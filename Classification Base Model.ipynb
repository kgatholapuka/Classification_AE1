# %% [markdown]
# # Advanced Classification- Predict

# %% [markdown]
# ## Introduction

# %%
import nltk

import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# For visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# For precision, recall, etc.
from sklearn.metrics import classification_report

# %%
train = pd.read_csv('train.csv')

# %%
train_df = train.copy()

# %%
train_df.head()
# Out:
#                                              message  tweetid  sentiment
# 0  polyscimajor epa chief doesn't think carbon di...   625221          1
# 1  it's not like we lack evidence of anthropogeni...   126103          1
# 2  rt @rawstory: researchers say we have three ye...   698562          2
# 3  #todayinmaker# wired : 2016 was a pivotal year...   573736          1
# 4  rt @soynoviodetodas: it's 2016, and a racist, ...   466954          1

# %% [markdown]
# Reorder columns so that our predicted variable is the last column of the dataframe

# %%
column_titles = [col for col in train_df.columns if col!= 'sentiment'] + ['sentiment']
train_df = train_df.reindex(columns=column_titles)

# %% [markdown]
# X = train_df.iloc[:, :-1]
#
# y = train_df.iloc[:, -1]

# %% [markdown]
# We'll print off a list of all the sentiment analysis polarity in this dataset:

# %%
sentiments_list = list(train_df.sentiment.unique())
print(sentiments)
# Out:
# {}

# %%
plt.hist(train['sentiment'], label='data');

plt.show()

# %% [markdown]
# ## Text Cleaning
#
# ### Removing Noise

# %% [markdown]
# When performing text analytics, removing noise (i.e. unneccesary information) is instrumental in getting the data into a usable format.
#
# For the Tweeter dataset we will be doing the following steps:
#
# - making everything lower case
# - removing punctuation

# %% [markdown]
# First we make all text lower case to remove noise due to capitalization:

# %%
train_df['message'] = train_df['message'].str.lower()

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def remove_punctuation(post):
    return ''.join([l for l in post if l not in string.punctuation])

# %%
train_df['message'] = train_df['message'].apply(remove_punctuation)
train_df['message'].iloc[2]
# Out:
# 'rt rawstory researchers say we have three years to act on climate change before it’s too late httpstcowdt0kdur2f httpstcoz0anpt…'

# %% [markdown]
# ### Tokenization
#
# A tokeniser divides text into a sequence of tokens, which roughly correspond to "words". Here we use use tokenisers to clean up the data, **making it ready for analysis**.
#
# We use tokenization function `TreebankWordTokenizer` from the `nltk.tokenize` library:

# %% [markdown]
# #Import the necessary modules
# from nltk.tokenize import regexp_tokenize
# from nltk.tokenize import TweetTokenizer
# #Use the TweetTokenizer to tokenize all tweets into one list
# tknzr = TweetTokenizer()
# all_tokens = [tknzr.tokenize(t) for t in tweets]
# print(all_tokens)

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
#Try Tweet tokenizer
tokeniser = TreebankWordTokenizer()
train_df['tokens'] = train_df['message'].apply(tokeniser.tokenize)
train_df['tokens'].iloc[5]
# Out:
# ['worth',
#  'a',
#  'read',
#  'whether',
#  'you',
#  'do',
#  'or',
#  'dont',
#  'believe',
#  'in',
#  'climate',
#  'change',
#  'httpstcogglzvnyjun',
#  'httpstco7afe2mah8j']

# %% [markdown]
# ### Stemming
#
# **NB!!!!!!!!**
#
# consider removig urls and emojis. Also consider stemming and removing stop words moving forward
#
# Also consider adding rt to the stopwords

# %% [markdown]
# ## Text feature extraction
# ### Bag of words

# %% [markdown]
# **EDIT THIS!!!!!!!!!!**
#
# Text feature extraction is the process of transforming what is essentially a list of words into a feature set that is usable by a classifier. The NLTK classifiers expect `dict` style feature sets, so we must therefore transform our text into a `dict`. The Bag of Words model is the simplest method; it constructs a word presence feature set from all the words in the text, indicating the number of times each word has appeared.

# %%
def bag_of_words_count(words, word_dict={}):
    """ this function takes in a list of words and returns a dictionary 
        with each word as a key, and the value represents the number of 
        times that word appeared"""
    for word in words:
        if word in word_dict.keys():
            word_dict[word] += 1
        else:
            word_dict[word] = 1
    return word_dict

# %%
sentiments = {}
for sent in sentiments_list:
    df = train_df.groupby('sentiment')
    sentiments[sent] = {} # make the personality type the main key
    for row in df.get_group(sent)['tokens']: # gets the pp group and its tokens
        sentiments[sent] = bag_of_words_count(row, sentiments[sent]) # gives bag of ords for each personality

# %%
df.get_group(1).head()
# Out:
#                                              message  tweetid  sentiment  \
# 0  polyscimajor epa chief doesnt think carbon dio...   625221          1
# 1  its not like we lack evidence of anthropogenic...   126103          1
# 3  todayinmaker wired  2016 was a pivotal year in...   573736          1
# 4  rt soynoviodetodas its 2016 and a racist sexis...   466954          1
# 5  worth a read whether you do or dont believe in...   425577          1
#
#                                               tokens
# 0  [polyscimajor, epa, chief, doesnt, think, carb...
# 1  [its, not, like, we, lack, evidence, of, anthr...
# 3  [todayinmaker, wired, 2016, was, a, pivotal, y...
# 4  [rt, soynoviodetodas, its, 2016, and, a, racis...
# 5  [worth, a, read, whether, you, do, or, dont, b...

# %%
sentiments
# Out:
# {1: {'polyscimajor': 1,
#   'epa': 268,
#   'chief': 66,
#   'doesnt': 718,
#   'think': 234,
#   'carbon': 96,
#   'dioxide': 35,
#   'is': 2841,
#   'main': 25,
#   'cause': 108,
#   'of': 2604,
#   'global': 1594,
#   'warming': 1410,
#   'and': 1888,
#   'wait': 25,
#   'what': 353,
#   'httpstcoyelvcefxkc': 1,
#   'via': 183,
#   'mashable': 19,
#   'its': 530,
#   'not': 673,
#   'like': 273,
#   'we': 1192,
#   'lack': 15,
#   'evidence': 72,
#   'anthropogenic': 10,
#   'todayinmaker': 1,
#   'wired': 14,
#   '2016': 53,
#   'was': 210,
#   'a': 2680,
#   'pivotal': 3,
#   'year': 81,
#   'in': 2421,
#   'the': 4769,
#   'war': 57,
#   'on': 1361,
#   'climate': 7346,
#   'change': 6968,
#   'httpstco44wotxtlcd': 1,
#   'rt': 5796,
#   'soynoviodetodas': 1,
#   'racist': 30,
#   'sexist': 12,
#   'denying': 121,
#   'bigot': 6,
#   'leading': 60,
#   'polls': 4,
#   'electionnight': 10,
#   'worth': 12,
#   'read': 69,
#   'whether': 33,
#   'you': 910,
#   'do': 326,
#   'or': 221,
#   'dont': 341,
#   'believe': 1001,
#   'httpstcogglzvnyjun': 1,
#   'httpstco7afe2mah8j': 1,
#   'thenation': 1,
#   'mike': 8,
#   'pence': 13,
#   'doesn’t': 12,
#   'that': 947,
#   'smoking': 5,
#   'causes': 40,
#   'lung': 1,
#   'cancer': 3,
#   'httpstcogvwyaauu8r': 1,
#   'makeandmendlife': 1,
#   'six': 11,
#   'big': 89,
#   'things': 78,
#   'can': 415,
#   'all': 310,
#   'today': 110,
#   'to': 4314,
#   'fight': 283,
#   'how': 825,
#   'be': 587,
#   'activistã¢â‚¬â¦': 1,
#   'httpstcotymlu6dbnm': 1,
#   'hã¢â‚¬â¦': 9,
#   'aceofspadeshq': 1,
#   'my': 166,
#   '8yo': 1,
#   'nephew': 1,
#   'inconsolable': 1,
#   'he': 233,
#   'wants': 70,
#   'die': 394,
#   'old': 48,
#   'age': 32,
#   'me': 163,
#   'but': 531,
#   'will': 626,
#   'perish': 1,
#   'fiery': 1,
#   'hellscape': 1,
#   'paigetweedy': 1,
#   'no': 298,
#   'offense…': 1,
#   'like…': 1,
#   'just': 369,
#   'believe…': 2,
#   'warming………': 1,
#   'stephenschlegel': 307,
#   'shes': 626,
#   'thinking': 337,
#   'about': 1152,
#   'going': 590,
#   'because': 478,
#   'your': 598,
#   'husband': 312,
#   'httpstcosjofonã¢â‚¬â¦': 307,
#   'i': 683,
#   'hope': 72,
#   'people': 453,
#   'who': 607,
#   'are': 863,
#   'vocal': 1,
#   'also': 118,
#   'powering': 1,
#   'their': 103,
#   'homes': 4,
#   'with': 492,
#   'renewable': 24,
#   'energy': 115,
#   'goodenergy': 2,
#   'alifaith55': 1,
#   'oh': 29,
#   'god': 46,
#   'trumps': 154,
#   'government': 64,
#   'removes': 4,
#   'page': 22,
#   'from': 404,
#   'website': 40,
#   'hours': 3,
#   'ahead': 9,
#   'climatemarch': 13,
#   'httpstco9z…': 1,
#   'glblctzn': 6,
#   'wan': 25,
#   'na': 65,
#   'live': 35,
#   'forever': 1,
#   '–': 42,
#   'nothing': 55,
#   '����️��': 1,
#   'taylorswift13': 1,
#   'zaynmalik': 1,
#   'httpstcotui64zk9gv': 1,
#   'jackholmes0': 1,
#   'issues': 49,
#   'scrubbed': 1,
#   'httpstcot1vzso9n7g': 1,
#   'civil': 13,
#   'rights': 85,
#   'lgbt': 25,
#   'healthcare…': 1,
#   'patagonia': 6,
#   'if': 511,
#   'our': 464,
#   'elected': 70,
#   'leaders': 47,
#   'fail': 13,
#   'approach': 18,
#   'environment': 108,
#   'amp': 654,
#   'as': 455,
#   'serious': 46,
#   'worthy': 5,
#   'urgency': 10,
#   'action': 198,
#   'it': 727,
#   'wiã¢â‚¬â¦': 8,
#   'sensanders': 249,
#   'have': 715,
#   'presidentelect': 193,
#   'millions': 154,
#   'say': 245,
#   'mr': 151,
#   'tã¢â‚¬â¦': 153,
#   'c40cities': 21,
#   '46': 4,
#   'c40': 2,
#   'mayors': 6,
#   'representing': 3,
#   '250m': 1,
#   'citizens': 17,
#   'urged': 1,
#   'g20': 9,
#   'saveourplanet': 1,
#   'too…': 2,
#   'worldwildlife': 10,
#   'impacts': 71,
#   'wildlife': 12,
#   'httpstcooztap4cdlk': 3,
#   'cop22': 71,
#   'earthtomarrakech': 9,
#   'httpstcoxm5xgpvhqy': 3,
#   'httpstcokynibjmdk5': 1,
#   'scientists': 173,
#   'wiped': 5,
#   'out': 191,
#   'an': 301,
#   'entire': 30,
#   'underwater': 16,
#   'ecosystem': 7,
#   'again': 40,
#   'climateã¢â‚¬â¦': 3,
#   'httpstcovzvjd3oxmi': 1,
#   'tammygrubb': 1,
#   'obama': 44,
#   'raises': 3,
#   'better': 47,
#   'vote': 81,
#   'for': 1144,
#   'candidates': 6,
#   'science': 244,
#   'obamaunc': 1,
#   'hate': 20,
#   'this': 744,
#   'mental': 4,
#   'health': 76,
#   'pretty': 17,
#   'low': 8,
#   'menu': 2,
#   'when': 257,
#   'hits': 9,
#   'food': 47,
#   'production': 16,
#   'an…': 5,
#   'httpstcokgfpw1hmpw': 1,
#   'hey': 38,
#   'there': 193,
#   'michaels': 1,
#   'vetted': 1,
#   'approved': 2,
#   'marketbased': 2,
#   'strategies': 6,
#   'tackling': 35,
#   'supported': 8,
#   'by': 563,
#   'majority': 29,
#   'cdns': 1,
#   'cdnpoli': 5,
#   'startalkradio': 1,
#   'first': 125,
#   'public': 41,
#   'understands': 13,
#   'than': 152,
#   'congress': 18,
#   'why': 230,
#   'johnholdren': 1,
#   'corybooker': 3,
#   'neiltyson': 8,
#   'explain': 28,
#   'htt…': 40,
#   'honey17011': 1,
#   'guide': 2,
#   'paris': 58,
#   'pact': 6,
#   'us': 440,
#   'role': 38,
#   'demforce': 1,
#   'theresistance': 8,
#   'uniteblue': 2,
#   'httpstcoryiblwajz4': 1,
#   'ignores': 8,
#   'basic': 7,
#   'bgr': 1,
#   'china': 107,
#   'practically': 2,
#   'says': 125,
#   'trump': 895,
#   'lied': 9,
#   'httpstcorz37htcs8d': 1,
#   'berniesanders': 124,
#   'imvotingbecause': 62,
#   'future': 154,
#   'planet': 183,
#   'at': 428,
#   'stake': 70,
#   'hillary': 78,
#   'clinton': 81,
#   'combat': 133,
#   'donald': 196,
#   'thinks': 218,
#   'iã¢â‚¬â¦': 76,
#   'deborahehart': 1,
#   'toxic': 4,
#   'soils': 11,
#   'aquifers': 1,
#   'vast': 4,
#   'amts': 1,
#   'wasted': 6,
#   'waste': 25,
#   'water': 87,
#   'runaway': 5,
#   'part': 59,
#   'gas': 21,
#   'fracking': 14,
#   'don…': 1,
#   'bettybowers': 1,
#   'america': 115,
#   'where': 92,
#   '“unproven”': 1,
#   '100': 58,
#   'sure': 30,
#   'guy': 40,
#   'called': 52,
#   'noah': 2,
#   'fit': 3,
#   'worlds': 39,
#   'animals': 24,
#   'hi…': 1,
#   'foramerica': 1,
#   'they': 211,
#   'protested': 1,
#   'support': 60,
#   'womansmarch': 1,
#   'then': 85,
#   'did': 49,
#   'help': 125,
#   'https…': 229,
#   'thedailybeast': 4,
#   'denial': 122,
#   'could': 137,
#   'cost': 26,
#   'trillion': 5,
#   'httpstcoklttt4sxrg': 1,
#   'httpstcogo1ycr48up': 1,
#   'anyone': 30,
#   'supports': 17,
#   'view': 23,
#   'non': 1,
#   'polluter': 5,
#   'cronie': 1,
#   'please': 76,
#   'step': 24,
#   'forward': 22,
#   'resist': 25,
#   'impeach': 2,
#   'httpstcoofob3utail': 1,
#   'hes': 73,
#   'president': 209,
#   'united': 44,
#   'states': 67,
#   'fuck': 28,
#   'kelkulus': 11,
#   'irony': 13,
#   'florida': 60,
#   'state': 48,
#   'danger': 25,
#   'being': 105,
#   'washed': 13,
#   'away': 29,
#   'due': 111,
#   'rising': 44,
#   'sea': 68,
#   'levels': 41,
#   'denies': 83,
#   'changeã¢â‚¬â¦': 49,
#   'greenpeaceeasia': 1,
#   'pollution': 45,
#   'india': 20,
#   'has': 302,
#   'reached': 6,
#   'stratosphere': 1,
#   'which': 79,
#   'speed': 6,
#   'up': 213,
#   'warming…': 20,
#   'unep': 18,
#   'citiesclimfin': 1,
#   'lays': 2,
#   'cities': 68,
#   'subnational': 1,
#   'bodies': 2,
#   'finance': 1,
#   'solutions': 39,
#   'hoax': 259,
#   'though': 17,
#   'httpstcopzugb9wfwt': 1,
#   'two': 21,
#   'cents': 2,
#   'political': 50,
#   'leadership': 30,
#   'era': 5,
#   'httpstcoi60iqxyty9': 1,
#   'motherjones': 11,
#   'here': 156,
#   'races': 4,
#   'watch': 153,
#   'care': 98,
#   'httpstco89hikysg3r': 1,
#   'httpstcosyxkddd6xe': 1,
#   'profpcdoherty': 1,
#   'need': 233,
#   'economists': 1,
#   'incorporate': 2,
#   'reality': 48,
#   'listen': 41,
#   'httpstcoliv…': 1,
#   'ushrn': 1,
#   'human': 87,
#   'were': 122,
#   'facing': 21,
#   'disastrous': 3,
#   'httpstcoq9ag2ex1oq…': 1,
#   'ahamiltonspirit': 1,
#   'question': 23,
#   'manmade': 45,
#   'doubts': 5,
#   'havent': 7,
#   'seen': 13,
#   'inconvenient': 9,
#   'truth': 29,
#   'please…': 2,
#   'alphageekst3r': 1,
#   'process': 4,
#   'occurs': 1,
#   'naturally': 2,
#   'these': 91,
#   'extreme': 35,
#   'well': 91,
#   'eventually': 4,
#   'severe': 8,
#   'droughts': 10,
#   'roschneider86': 1,
#   'neoliberalism': 8,
#   'conned': 7,
#   'into': 56,
#   'fighting': 102,
#   'individuals': 10,
#   'martin': 10,
#   'lukacs': 4,
#   'httpstcog6mhojzxa1': 1,
#   'davidsirota': 19,
#   'must': 163,
#   'rick': 18,
#   'perry': 20,
#   'ordered': 3,
#   'texas': 15,
#   'legislature': 1,
#   'kill': 46,
#   'bill': 31,
#   'requiring': 2,
#   'agencies': 6,
#   'prepare': 13,
#   'doesnã¢â‚¬â„¢t': 58,
#   'thatã¢â‚¬â„¢s': 37,
#   'frightening': 38,
#   'country': 107,
#   'world': 444,
#   'so': 289,
#   'hot': 30,
#   'verge': 9,
#   'google': 12,
#   'earth’s': 3,
#   'timelapse': 7,
#   'update': 4,
#   'illustrates': 3,
#   '30': 17,
#   'years': 132,
#   'httpstcoktduwzasfc': 1,
#   'httpstconzz8tyt7i4': 1,
#   'sethmacfarlane': 66,
#   'hrc': 61,
#   'proposes': 57,
#   'installing': 56,
#   'half': 74,
#   'billion': 81,
#   'solar': 73,
#   'panels': 60,
#   'end': 120,
#   'her': 78,
#   'term': 72,
#   'hoaxã¢â‚¬â¦': 56,
#   'beforetheflood': 148,
#   'everyone': 56,
#   'understand': 45,
#   'very': 69,
#   'real': 487,
#   'leodicaprio': 121,
#   'httpstcovtqnt1f6ni': 1,
#   'shake': 1,
#   'ever': 56,
#   'httpstcoyhpje56lyp': 1,
#   'earthjustice': 3,
#   'noaa': 15,
#   'report': 30,
#   '2nd': 12,
#   'hottest': 19,
#   'history': 27,
#   'one': 174,
#   'more': 357,
#   'reason': 26,
#   'deniers': 180,
#   'admin': 25,
#   'gt…': 1,
#   'conservatives': 30,
#   'love': 24,
#   'huh': 7,
#   'believing': 18,
#   'fertilization': 1,
#   'egg': 2,
#   'automatic': 1,
#   'life': 32,
#   'come': 41,
#   'check': 33,
#   'events': 12,
#   'srhpl': 1,
#   'httpstco8yviyn22lo': 1,
#   '200': 7,
#   'million': 19,
#   'gone': 16,
#   'towards': 17,
#   'alleviating': 1,
#   'poverty': 22,
#   'reducing': 11,
#   'improving': 3,
#   'healthcare': 22,
#   'call': 49,
#   'mad': 10,
#   'ronaldklain': 1,
#   'decides': 2,
#   'briancdeese': 1,
#   'team': 24,
#   'washingtonpost': 27,
#   'warn': 6,
#   'epidemics': 1,
#   'savingoceans': 2,
#   'potentially': 2,
#   'hurt': 11,
#   'fishermen': 3,
#   'jobs': 51,
#   'httpstco5md2qw4vtc': 1,
#   '“yet': 1,
#   'another': 63,
#   'advisor': 7,
#   'clueless': 5,
#   'change”': 17,
#   'climateprogress': 5,
#   'httpstcoapamiibdjj': 1,
#   'director': 8,
#   'denier': 185,
#   'coal': 56,
#   'lobbies': 1,
#   'deputy': 3,
#   'environment…': 2,
#   'httpstcoxlxhbwnjum': 1,
#   'irisrimon': 1,
#   'chinese': 152,
#   'broke': 12,
#   'massive': 15,
#   'iceberg': 9,
#   'antarctica': 10,
#   'ndenicolamd': 1,
#   '500000': 1,
#   'doctors': 5,
#   'agree': 52,
#   'making': 58,
#   'sick': 12,
#   'earthday': 11,
#   'marchforscience': 7,
#   'healthandclimate…': 1,
#   'tristinc1': 2,
#   'made': 69,
#   'vice': 10,
#   'gay': 25,
#   'curable': 2,
#   'diseaseã¢â‚¬â¦': 2,
#   'looking': 31,
#   'officially': 10,
#   'believes': 90,
#   'sorry': 23,
#   'everybody': 11,
#   'else': 18,
#   'realdonaldtrump': 166,
#   'potus': 41,
#   'fucking': 42,
#   'idiot': 13,
#   'im': 142,
#   'geologist': 1,
#   'studied': 4,
#   'college': 11,
#   'coauthored': 1,
#   'papers': 3,
#   'natgeochannel': 122,
#   'right': 194,
#   'travels': 76,
#   'tackle': 126,
#   'httpstcolkdehj3tnn': 73,
#   'httã¢â‚¬â¦': 92,
#   'peta': 6,
#   'meat': 26,
#   'deforestation': 21,
#   'extinction': 18,
#   'worldvegandayã¢â‚¬â¦': 3,
#   'lexi4prez': 2,
#   'literally': 51,
#   'denierrip': 1,
#   'httpstcob67iq8n9fs': 1,
#   'only': 150,
#   'kloppholic': 3,
#   'imagine': 22,
#   'trying': 29,
#   'convince': 11,
#   'yourself': 10,
#   'isnt': 183,
#   'instead': 39,
#   'conspiracy': 23,
#   'wake': 16,
#   'before': 82,
#   'docrock1007': 1,
#   'saying': 47,
#   'every': 91,
#   'major': 72,
#   'scientific': 55,
#   'organization': 5,
#   'follow': 15,
#   'projectarcc': 2,
#   'want': 131,
#   'hear': 26,
#   'av': 1,
#   'digital': 5,
#   'archivists': 1,
#   'activism': 1,
#   'avhack16': 1,
#   'look': 86,
#   'polar': 34,
#   'bears': 25,
#   'extinct': 10,
#   'land': 10,
#   'antivaccersclimate': 1,
#   'deniersaca': 1,
#   'killers': 1,
#   'stop': 165,
#   'using': 20,
#   'stupidity': 4,
#   'try': 24,
#   'kil…': 1,
#   'httpstcocrdjkmqdxx': 1,
#   'see': 129,
#   'httpstconsde3zvmh4': 1,
#   'way': 90,
#   'avert': 3,
#   'should': 186,
#   'apply': 6,
#   'method': 3,
#   'httpstcotj8n6zmwqo': 1,
#   'samjamesvelde': 2,
#   '90': 9,
#   'degrees': 84,
#   'early': 9,
#   'november': 53,
#   'los': 3,
#   'angeles': 2,
#   'know': 190,
#   'according': 11,
#   'art4climate': 1,
#   'larsenc': 1,
#   'climatechangeart…': 1,
#   'httpstco1jogxqk1nn': 1,
#   'youths': 3,
#   'almost': 29,
#   '60': 11,
#   'kenyas': 1,
#   'pop': 2,
#   'best': 59,
#   'line': 17,
#   'defense': 28,
#   'against': 193,
#   'security': 42,
#   'robertmburia': 1,
#   'richardmunang': 7,
#   'geographerjay': 1,
#   'nasa': 59,
#   'research': 63,
#   'estate': 3,
#   'markets': 3,
#   'start': 65,
#   'slump': 1,
#   'httpstco…': 86,
#   'jeffdsachs': 2,
#   'cnn': 60,
#   'panelists': 1,
#   'erupt': 1,
#   'over': 131,
#   'video': 23,
#   'time': 140,
#   'lies': 9,
#   'koch': 5,
#   'brothers': 3,
#   'heritage': 3,
#   'httpst…': 107,
#   'worried': 33,
#   'effect': 23,
#   'methane': 11,
#   '25': 3,
#   'greater': 5,
#   'thought': 24,
#   'httpstcox68jxuiodt': 1,
#   'physorgcom': 2,
#   'astrokatie': 27,
#   'governments': 10,
#   'several': 4,
#   'powers': 2,
#   'failing': 11,
#   'act': 71,
#   'without': 44,
#   'them': 77,
#   'any': 76,
#   'kamalaharris': 38,
#   'stand': 36,
#   'jerrybrowngov': 12,
#   'california': 32,
#   'back': 75,
#   'down': 65,
#   'httpstcoxp8y6esmyx': 10,
#   'steveengland300': 1,
#   'u': 73,
#   'considered': 4,
#   'doing': 52,
#   'piece': 15,
#   'column': 6,
#   'steve': 6,
#   'inform': 2,
#   'ppl': 36,
#   're': 15,
#   'impact': 61,
#   'species': 32,
#   'habitats': 2,
#   'benwikler': 1,
#   'worry': 41,
#   'natural': 43,
#   'rendering': 2,
#   'earth': 151,
#   'uninhabitable': 4,
#   'alanresnicks': 1,
#   '5': 28,
#   'horsemen': 1,
#   'apocalypse': 3,
#   'famine': 9,
#   'death': 12,
#   'pestilence': 1,
#   'hawaiidelilah': 2,
#   'went': 11,
#   'ivanka': 9,
#   'reporter': 1,
#   'insights': 4,
#   'women': 66,
#   'expertis…': 1,
#   'wqs': 1,
#   'pakistan': 10,
#   '5th': 2,
#   'most': 141,
#   'vulnerable': 23,
#   'terms': 13,
#   'whats': 26,
#   'experienced': 6,
#   'prime': 4,
#   'minister': 9,
#   'about…': 2,
#   '1957ajb': 1,
#   'knock': 1,
#   'ourselves': 8,
#   'brexit': 7,
#   'bury': 4,
#   'both': 26,
#   'those': 62,
#   'issuesbut': 1,
#   'really': 133,
#   'w…': 10,
#   'drop': 7,
#   'dead': 19,
#   'nobel': 2,
#   'scientist': 63,
#   'such': 25,
#   'ignorance': 17,
#   'shocking': 7,
#   'httpstcorb4bfxp63j': 1,
#   'lastweektonight': 16,
#   'donã¢â‚¬â„¢t': 16,
#   'silly': 16,
#   'issue': 112,
#   'give': 73,
#   'resources': 57,
#   'council': 17,
#   'httpsã¢â‚¬â¦': 74,
#   'deanofcomedy': 4,
#   'followed': 2,
#   'closely': 3,
#   'wall': 19,
#   'street': 5,
#   'executives': 3,
#   'sdg13': 2,
#   'take': 146,
#   'urgent': 19,
#   'join': 75,
#   'movementã¢â‚¬â¦': 1,
#   'httpstcobqxz5zkbjv': 1,
#   'bradleym4': 1,
#   'juddlegum': 3,
#   '14': 2,
#   'yo': 8,
#   'kid': 5,
#   'fact': 70,
#   'matte…': 1,
#   'calls': 33,
#   'itã¢â‚¬â„¢s': 13,
#   'bad': 61,
#   'httpstcoukxypvuvjf': 1,
#   'billmckibben': 21,
#   'exxonmobil': 9,
#   'long': 23,
#   'peddling': 2,
#   'misinformation': 6,
#   'elizkolbert': 3,
#   'newyorker': 2,
#   'exxonknew': 9,
#   'mrdenmore': 4,
#   'apart': 4,
#   'taking': 54,
#   'brink': 1,
#   'recession': 1,
#   'doubling': 2,
#   'deficit': 1,
#   'pariah': 3,
#   'refugees': 14,
#   'th…': 21,
#   'easiest': 4,
#   'ways': 41,
#   'daily': 19,
#   'eating': 15,
#   'beef': 7,
#   'heres': 81,
#   'whyã¢â‚¬â¦': 3,
#   'effects': 91,
#   'httpstco6eytztqlow': 1,
#   'marcuschown': 1,
#   'white': 66,
#   'house': 50,
#   'deal': 52,
#   'catastrophe': 20,
#   'threatens': 14,
#   '75': 9,
#   'withã¢â‚¬â¦': 1,
#   'argue': 13,
#   'new': 282,
#   'httpstcothknouk8d1': 1,
#   'httpstcomx8vpqu…': 1,
#   'turnscoat': 1,
#   'cant': 102,
#   'number': 18,
#   'priority': 10,
#   'mobilizeclimate': 2,
#   'treating': 6,
#   'some': 88,
#   'far': 27,
#   'off': 76,
#   'doomsday': 2,
#   'now': 291,
#   'jacobwhitesides': 4,
#   'thats': 80,
#   'christmas': 16,
#   'httpstcovvazjvxh6w': 4,
#   'chejackson': 1,
#   'anything': 34,
#   'columbus': 1,
#   'rex': 15,
#   'tillerson': 16,
#   'refuses': 11,
#   'admit': 11,
#   'decades': 26,
#   'ago': 26,
#   'httpstcorxq6xgfqux': 1,
#   'huffpostpol': 14,
#   'wakmax': 1,
#   'talk': 87,
#   'alicebell': 2,
#   'itll': 5,
#   'make': 159,
#   'feel': 18,
#   'go': 88,
#   'httpstcon1v…': 1,
#   'duycks': 1,
#   'tomorrow': 12,
#   'hrc35': 1,
#   'event': 9,
#   'childrenrights': 1,
#   'context': 8,
#   'key': 31,
#   'message': 16,
#   'protect': 45,
#   'empower…': 1,
#   'boost': 4,
#   'funding': 31,
#   'developing': 4,
#   'countries': 54,
#   'adapt': 14,
#   'cop22ã¢â‚¬â¦': 9,
#   'paulhbeckwith': 2,
#   'folks': 10,
#   'story': 35,
#   'evil': 3,
#   'twin': 1,
#   'oceans': 20,
#   'acid': 2,
#   'httpstcosjjgkcrlyk…': 1,
#   'adriangeolopez': 1,
#   'still': 165,
#   '��\u200d♂️': 1,
#   'especially': 15,
#   'pulling': 3,
#   'p…': 11,
#   'fitness': 1,
#   'too': 78,
#   'late': 20,
#   'reverse': 18,
#   'warmingampquot': 1,
#   'to…': 12,
#   'httpstco9maamvwdlr': 1,
#   'scholaurship': 1,
#   'motherfucker': 1,
#   'arizonapatriot1': 1,
#   'joelpollak': 1,
#   'gabyendingstory': 1,
#   'least': 23,
#   'christianextremist': 1,
#   'evolution': 27,
#   'hoaxes': 3,
#   'natgeophotos': 3,
#   'although': 4,
#   'scary': 19,
#   'topic': 10,
#   'ice': 85,
#   'insanely': 1,
#   'unimaginably': 1,
#   'beautifulhttpstcodhhxzzdtv6': 1,
#   '2': 94,
#   'everyones': 3,
#   'something': 49,
#   'progressive': 6,
#   'env': 2,
#   'exxon': 38,
#   'hero': 2,
#   'kicked': 1,
#   'saving': 5,
#   'selected': 1,
#   'money': 37,
#   'httpstcojbefwiv6wf': 1,
#   'include': 5,
#   'job': 17,
#   'losses': 3,
#   'business': 25,
#   'interruptions': 1,
#   'worsening': 9,
#   'working': 38,
#   'httpstcoofcg3dlhrs': 1,
#   'un': 54,
#   'c0nvey': 9,
#   'taylorandbrown': 1,
#   'thing': 98,
#   'bothers': 2,
#   'defund': 2,
#   'reã¢â‚¬â¦': 11,
#   'illuminateboys': 1,
#   'politicians': 37,
#   'fake': 48,
#   'ourã¢â‚¬â¦': 7,
#   'jamespeshaw': 2,
#   'nzgreens': 2,
#   'gets': 26,
#   'zealand': 4,
#   'clean': 53,
#   'shadbase': 2,
#   'conversationedu': 2,
#   'turtles': 1,
#   'been': 80,
#   'around': 61,
#   '150': 3,
#   'pace': 4,
#   'existential': 10,
#   'challengeã¢â‚¬â¦': 1,
#   'lawlib': 1,
#   'board': 11,
#   'bouncing': 3,
#   'ideas': 15,
#   'interested': 11,
#   'httpstcoltvc09rfhf': 3,
#   'lisalsong': 1,
#   'horrifying': 6,
#   'outcomes': 1,
#   'stevevsninjas': 1,
#   '10ã‚â°f': 1,
#   'lie': 10,
#   ...},
#  2: {'rt': 2151,
#   'rawstory': 5,
#   'researchers': 28,
#   'say': 62,
#   'we': 64,
#   'have': 97,
#   'three': 6,
#   'years': 60,
#   'to': 1624,
#   'act': 17,
#   'on': 791,
#   'climate': 3327,
#   'change': 3139,
#   'before': 12,
#   'it’s': 11,
#   'too': 12,
#   'late': 7,
#   'httpstcowdt0kdur2f': 1,
#   'httpstcoz0anpt…': 1,
#   'tveitdal': 10,
#   'only': 19,
#   'a': 537,
#   '5': 4,
#   'percent': 9,
#   'chance': 5,
#   'of': 801,
#   'avoiding': 4,
#   '‘dangerous’': 2,
#   'global': 503,
#   'warming': 425,
#   'study': 97,
#   'finds': 34,
#   'httpstcoxubtqnxhkk': 1,
#   'httpstcoof…': 1,
#   'fossil': 8,
#   'fuel': 5,
#   'giant': 7,
#   'exxonmobil': 12,
#   '‘misled’': 1,
#   'the': 1129,
#   'public': 20,
#   'about': 162,
#   'harvard': 11,
#   'academics': 2,
#   'conclude': 2,
#   'httpstcoofc2wsu4ex': 1,
#   'bangladesh': 5,
#   'confronting': 1,
#   'head': 76,
#   'httpstcomtqenbqdut': 1,
#   'httpstcoitgkuxgefg': 1,
#   'latimes': 22,
#   'atmospheric': 2,
#   'rivers': 3,
#   'fueled': 4,
#   'by': 232,
#   'could': 133,
#   'decimate': 2,
#   'wild': 5,
#   'oysters': 5,
#   'in': 599,
#   'san': 8,
#   'francisco': 5,
#   'bay': 8,
#   'httpstcop0lzbhlu5k': 1,
#   'httpst…': 55,
#   'independent': 54,
#   'trumps': 165,
#   'team': 30,
#   'removed': 5,
#   'data': 31,
#   'from': 252,
#   'white': 55,
#   'house': 69,
#   'website': 66,
#   'they': 18,
#   'may': 93,
#   'be': 106,
#   'breaking': 21,
#   'law…': 2,
#   '2050': 8,
#   'targets': 8,
#   'nations': 16,
#   'are': 194,
#   'playing': 1,
#   'long': 2,
#   'game': 7,
#   'fighting': 24,
#   'httpstcodnegw2vfjd': 1,
#   'via': 289,
#   'conversationedu': 3,
#   'washingtonpost': 45,
#   'alaskan': 3,
#   'tundra': 2,
#   'is': 408,
#   'filling': 1,
#   'atmosphere': 7,
#   'with': 188,
#   'carbon': 78,
#   'dioxide': 56,
#   'worsening': 1,
#   'httpstconsoimuweax': 1,
#   'thetorontosun': 1,
#   'sunlorrie': 2,
#   'indian': 12,
#   'environmentalist': 3,
#   'calls': 54,
#   'out': 59,
#   'dicaprio': 13,
#   'his': 39,
#   'own': 30,
#   'documentary': 5,
#   'changeã¢â‚¬â¦': 10,
#   'starbuck': 1,
#   'world': 114,
#   'food': 20,
#   'supplies': 4,
#   'at': 167,
#   'risk': 27,
#   'as': 170,
#   'threatens': 13,
#   'international': 20,
#   'trade': 28,
#   'warn': 20,
#   'experts': 44,
#   'httpstcorwcw2xf2lr': 1,
#   'foxnews': 14,
#   'macron': 13,
#   'my': 4,
#   'charm': 1,
#   'changed': 3,
#   'mind': 10,
#   'httpstcohxdjqwgbe5': 1,
#   'httpstco9idj2a5nzq': 1,
#   'these': 19,
#   'republicans': 22,
#   'real': 34,
#   'and': 432,
#   'time': 47,
#   'fight': 159,
#   'it': 101,
#   'ninaburleigh': 1,
#   'httpstcovnayfuhglw': 1,
#   'kylegriffin1': 9,
#   'nyt': 5,
#   'reviewed': 1,
#   'draft': 3,
#   'rpt': 1,
#   'fed': 1,
#   'scientists': 177,
#   'directly': 3,
#   'contradicting': 2,
#   'admins': 1,
#   'claims': 20,
#   'https…': 79,
#   'bbcbreaking': 6,
#   'uk': 39,
#   'government': 55,
#   'signs': 36,
#   'paris': 110,
#   'agreement': 80,
#   'worlds': 30,
#   'first': 26,
#   'comprehensive': 5,
#   'treaty': 11,
#   'tackling': 23,
#   'httpstcohdafst5pfcã¢â‚¬â¦': 5,
#   'us': 291,
#   'environmental': 30,
#   'agency': 35,
#   'chief': 100,
#   'says': 240,
#   'humans': 25,
#   'contribute': 2,
#   'httpstcoassz4eszxs': 1,
#   'thinkprogress': 17,
#   'where': 13,
#   'rex': 58,
#   'tillerson’s': 2,
#   'emails': 26,
#   'httpstcolyanhbpzft': 1,
#   '80': 1,
#   'ghg': 1,
#   'resevoirs': 2,
#   'methane': 6,
#   'play': 5,
#   'substantial': 1,
#   'role': 36,
#   'httpstcocnhiu818ky': 1,
#   'httpstco58nmafxcmp': 1,
#   'greenharvard': 2,
#   '“universities': 1,
#   'uniquely': 1,
#   'important': 5,
#   'battle': 26,
#   'against': 95,
#   'change”': 12,
#   'httpstcojrv2z1omrx': 1,
#   'popsci': 9,
#   'ten': 1,
#   'ugliest': 1,
#   'animals': 3,
#   'threatened': 12,
#   'httpstcou67evjeuno': 1,
#   'httpstcoihohxlqfts': 1,
#   'syfys': 1,
#   'incorporated': 1,
#   'imagines': 1,
#   'future': 16,
#   'ravaged': 1,
#   'httpstco7nb1ikzt72': 1,
#   'cnn': 78,
#   'httpstcob33c6bcsvy': 1,
#   'nytnational': 2,
#   'budget': 28,
#   'proposal': 7,
#   'we’re': 4,
#   'not': 142,
#   'spending': 9,
#   'money': 15,
#   'that': 160,
#   'anymore': 4,
#   'httpstco3f7y0eudpl': 1,
#   'air': 15,
#   'pollution': 14,
#   'deaths': 4,
#   'expected': 11,
#   'rise': 20,
#   'due': 59,
#   'httpstcoimoox1l1mg': 1,
#   'httpstcohdpng5jftp': 1,
#   'labour': 3,
#   'budgeting': 1,
#   '2': 6,
#   'punch': 1,
#   'httpstcomby8dek6cv': 1,
#   'climatechange': 63,
#   'foxandfriends': 2,
#   'new': 190,
#   'catholic': 1,
#   'priests': 3,
#   'preach': 2,
#   'congregations': 1,
#   'report': 72,
#   'foxnation…': 1,
#   'sasjabeslik': 2,
#   'meet': 25,
#   'chinaã¢â‚¬â„¢s': 2,
#   'ecological': 5,
#   'migrants': 2,
#   '320000': 2,
#   'people': 26,
#   'displaced': 4,
#   'httpstcomsyqcisug6ã¢â‚¬â¦': 2,
#   'china': 145,
#   'warns': 41,
#   'trump': 827,
#   'abandoning': 10,
#   'deal': 48,
#   'httpstcoz8e2bvl80c': 1,
#   'ft': 11,
#   'science': 96,
#   'rescue': 5,
#   'chocolate': 1,
#   'europe': 14,
#   'httpstcojefdvn4llt': 1,
#   'safetypindaily': 16,
#   'federal': 40,
#   'department': 48,
#   'censoring': 7,
#   'use': 28,
#   'term': 11,
#   'reveal': 10,
#   'olliemilman': 2,
#   'httpstco6usp4mub…': 1,
#   'conservative': 6,
#   'columnist': 3,
#   'under': 31,
#   'siege': 2,
#   'after': 60,
#   'ny': 17,
#   'times': 22,
#   'debut': 2,
#   'fox': 9,
#   'news': 122,
#   'httpstconhl8mnomda': 1,
#   'indyusa': 4,
#   'director': 6,
#   'just': 74,
#   'said': 18,
#   'combating': 4,
#   'waste': 14,
#   'money’': 1,
#   'httpstcofnad9xspym': 1,
#   'trudeau': 9,
#   'must': 21,
#   'put': 8,
#   'emphasis': 1,
#   'defence': 3,
#   'if': 44,
#   'he': 56,
#   'wants': 29,
#   'onside': 1,
#   'for': 348,
#   'httpstco7tod99m416': 1,
#   'nationalpost': 3,
#   'thehill': 82,
#   'rahm': 7,
#   'emanuel': 11,
#   'posts': 9,
#   'webpage': 12,
#   'deleted': 21,
#   'administration': 44,
#   'httpstconhk4nvsuc1': 1,
#   'httpstcotomkxl3owa': 1,
#   'energydesk': 4,
#   'historic': 5,
#   'coal': 30,
#   'fall': 4,
#   'profound': 1,
#   'impact': 43,
#   'efforts': 46,
#   'tackle': 29,
#   'httpstcof4qqorl6xm': 1,
#   'httpstco…': 51,
#   'literateliberal': 1,
#   'leading': 16,
#   'deniers': 9,
#   'told': 10,
#   'what': 74,
#   'want': 24,
#   'do': 26,
#   'httpstcotkzvnzddd3': 1,
#   'motherjones': 13,
#   'pablorodas': 14,
#   'p2': 13,
#   'west': 6,
#   'coast': 6,
#   'states': 32,
#   'even': 13,
#   'does': 25,
#   'httpstcodyixu8txak…': 1,
#   'ecointernet3': 23,
#   'secretary': 47,
#   'state': 45,
#   'tillerson': 71,
#   'arctic': 56,
#   'action': 55,
#   'antinuclear': 1,
#   'httpstco7de…': 1,
#   'stephen': 8,
#   'hawking': 5,
#   'has': 113,
#   'message': 14,
#   'dont': 25,
#   'ignore': 21,
#   'httpstco7ba3rbohk9': 1,
#   'httpstcouiqwwgz0pb': 1,
#   'telesurenglish': 1,
#   'one': 29,
#   'jamaica’s': 1,
#   'iconic': 2,
#   'beaches': 3,
#   'vanishing': 2,
#   'thanks': 14,
#   'httpstco2lnolt7mzm…': 1,
#   'nzaegel': 1,
#   'effects': 47,
#   'wreak': 1,
#   'havoc': 1,
#   'mental': 13,
#   'health': 33,
#   'doctors': 9,
#   'httpstcokhhj9l0nwu': 1,
#   'upi': 1,
#   'brace': 4,
#   'yourself': 4,
#   'bitterly': 4,
#   'cold': 6,
#   'winter': 16,
#   'shifts': 9,
#   'polar': 22,
#   'vortex': 11,
#   'httpstcotkrnpz6lix': 4,
#   'httpstcã¢â‚¬â¦': 5,
#   'business': 46,
#   'tells': 41,
#   'isnt': 29,
#   'hoax': 45,
#   'invented': 15,
#   'httpstcoewvqti28t3': 12,
#   'httpstco7qv3rfztte': 12,
#   'climatekeith': 1,
#   'saskatchewan': 1,
#   'ag': 19,
#   'provincial': 2,
#   'govt': 13,
#   'no': 43,
#   'plan': 88,
#   'policies': 30,
#   'or': 22,
#   'target': 8,
#   'address': 18,
#   'httpstcou1cjcapwai': 1,
#   'skpol…': 1,
#   'exxon': 78,
#   'shareholders': 6,
#   'moved': 2,
#   'force': 11,
#   'company': 10,
#   'disclose': 6,
#   'poses': 3,
#   'its': 90,
#   'business…': 1,
#   'natureorg': 5,
#   'leaders': 58,
#   'reaffirm': 5,
#   'their': 47,
#   'commitment': 9,
#   'parisagreement': 8,
#   'httpstcoqst5xtw9ai': 1,
#   'httpstcoabhã¢â‚¬â¦': 1,
#   'john': 28,
#   'roughan': 1,
#   'will': 153,
#   'miss': 1,
#   'sceptical': 1,
#   'voice': 5,
#   'zealand': 6,
#   'herald': 10,
#   'httpstco1y4eyjobym': 1,
#   'environment': 73,
#   'huffingtonpost': 17,
#   'chinese': 20,
#   'httpstco3dvliwaqjb': 1,
#   'ã¢å¾â¡ã¯â¸ï†\x8f': 2,
#   'cmdangelo': 3,
#   'httpstcoy1zqew8hcv': 1,
#   'businessinsider': 9,
#   'apple': 6,
#   'borrowing': 1,
#   '1': 8,
#   'billion': 16,
#   'httpstcoyfxylhmadd': 1,
#   'httpstcosboxh39ppg': 1,
#   'bradydennis': 2,
#   'cdc': 15,
#   'abruptly': 5,
#   'cancels': 11,
#   'longplanned': 4,
#   'conference': 23,
#   'httpstcohb8nxdfwaa': 1,
#   'river': 13,
#   'canada': 14,
#   'turned': 4,
#   'piracy': 1,
#   'because': 17,
#   'httpstco6qno8nc9nr': 1,
#   'httpstco2swiepthdz': 1,
#   'thedailyclimate': 2,
#   'frogs': 1,
#   'heading': 1,
#   'uphill': 1,
#   'escape': 1,
#   'india': 25,
#   'timesofindia': 1,
#   'httpstcoqsbqypdq2h': 1,
#   'campaigner': 7,
#   'dies': 6,
#   'snorkeling': 6,
#   'greatbarrierreef': 14,
#   'httpstcom1cfwd49an': 1,
#   'climatechangrr': 10,
#   'sends': 6,
#   '“much': 1,
#   'smaller”': 1,
#   'talks': 27,
#   'bonn': 1,
#   'home': 21,
#   'httpstcoesdfyzzsn0': 1,
#   'http…': 20,
#   'washtimes': 3,
#   'whistleblower': 5,
#   'alleges': 1,
#   'noaa': 10,
#   'manipulated': 6,
#   'hide': 1,
#   'pause': 4,
#   'noaa…': 1,
#   'reportedly': 2,
#   'used': 51,
#   'alias': 43,
#   'read': 10,
#   'more': 75,
#   'httpstcoobhqegkjph': 1,
#   'xom': 2,
#   'guardianeco': 26,
#   'stopping': 6,
#   'way': 29,
#   'save': 22,
#   'great': 28,
#   'barrier': 22,
#   'reef': 18,
#   'httpstcosdakfo93tr': 1,
#   'wsj': 16,
#   'rebuke': 6,
#   'policy': 50,
#   'ge': 8,
#   'ceo': 20,
#   'immelt': 2,
#   '‘climate': 12,
#   'real’': 2,
#   'httpstco5s95jekkot': 1,
#   'arnold': 8,
#   'schwarzenegger': 10,
#   'teams': 4,
#   'up': 62,
#   'httpstco6pj8p5lsyx': 1,
#   'httpstcodfpfmzrrh1': 1,
#   'end': 10,
#   'lead': 28,
#   'make': 38,
#   'again': 5,
#   '—': 43,
#   'guardian': 62,
#   'httpstco1slwmu2vcq': 1,
#   'ht…': 6,
#   'weneedhillary': 1,
#   'cbs': 8,
#   'evening': 1,
#   'donald': 162,
#   'skeptic': 21,
#   'charge': 4,
#   'protecting': 3,
#   'environment…': 3,
#   'drbobbullard': 1,
#   'ã¢â‚¬ëœthereã¢â‚¬â„¢s': 8,
#   'bã¢â‚¬â„¢': 8,
#   'fear': 28,
#   'consequence': 9,
#   'victory': 15,
#   'httpstcoaj131zjpyg': 1,
#   'googlegirl': 1,
#   '9': 3,
#   'sues': 4,
#   'over': 171,
#   'inaction': 13,
#   'httpstcomfjvbe37y2': 1,
#   'httpstcovu8aiv5hxw': 1,
#   'how': 125,
#   'obamas': 27,
#   'legacy': 5,
#   'weakened': 1,
#   'investment': 8,
#   'dirty': 2,
#   'httpstcoapmtf66rg3': 1,
#   'sabrush': 1,
#   'epa': 240,
#   'believe': 21,
#   'primary': 55,
#   'contributor': 48,
#   'httpstcoyd3ptnifh4': 1,
#   'picks': 6,
#   'sceptic': 4,
#   'scott': 112,
#   'pruitt': 96,
#   'httpstco1xb8rrw026': 1,
#   'cop22': 17,
#   'gma': 1,
#   'undergoing': 1,
#   'rapid': 12,
#   'ice': 40,
#   'melt': 18,
#   'speed': 2,
#   'httpstcojll8cn79qp': 1,
#   'httpstcobatuqntxcc': 1,
#   'vicenews': 6,
#   'trumpã¢â‚¬â„¢s': 9,
#   'rumored': 1,
#   'pick': 18,
#   'everyone': 4,
#   'ã¢â‚¬å“love': 1,
#   'warmingã¢â‚¬ï†\x9d': 1,
#   'httpstcoztvfkxcbah': 1,
#   'httpstcohlbrh3zglr': 1,
#   'ajplus': 15,
#   'top': 32,
#   'met': 1,
#   'g7': 25,
#   'summit': 26,
#   'today': 14,
#   'all': 32,
#   'countries': 27,
#   'affirmed': 1,
#   'theyd': 1,
#   '–': 44,
#   'except': 1,
#   'can…': 1,
#   'antarctica': 14,
#   'starting': 1,
#   'turn': 9,
#   'green': 25,
#   'httpstcophp1dqyo9d': 1,
#   'httpstcoblcu2caigp': 1,
#   'u': 2,
#   's': 2,
#   'opens': 2,
#   'water': 25,
#   'research': 53,
#   'facility': 1,
#   'httpstcoeduzd3m15q': 1,
#   'urged': 14,
#   'bbcnews': 2,
#   'geographyteacher': 1,
#   'httpstcodpekzsv6xt': 1,
#   'nytimes': 47,
#   'cooks': 1,
#   'decades': 8,
#   'ahead': 29,
#   'suffer': 5,
#   'equally': 1,
#   'httpstco2gv056tvex': 1,
#   'pope': 16,
#   'challenges': 6,
#   'un': 66,
#   'httpstcorwrkv0ciuq': 1,
#   'sdogbon': 1,
#   'mgwvjaiye': 1,
#   'httpstcofquoj42kvi': 1,
#   'changes': 17,
#   'course': 12,
#   'california': 53,
#   'stubbornly': 1,
#   'presses': 1,
#   'forward': 4,
#   'httpstcorkukntajgf': 1,
#   'drills': 4,
#   'tibet': 1,
#   'glaciers': 7,
#   'why': 30,
#   'morocco': 6,
#   'httpstco00ntxopnko': 1,
#   'record': 30,
#   'humancaused': 15,
#   'rerouted': 6,
#   'an': 101,
#   'entire': 12,
#   'httpstcoqv7vdpqxf8': 1,
#   'doubts': 12,
#   'dioxides': 1,
#   'bbc': 17,
#   'httpstco3iojhszkdm': 1,
#   'scrambling': 1,
#   'protect': 13,
#   'energized': 1,
#   'concerns': 5,
#   'administration…': 1,
#   'appolitics': 7,
#   'national': 42,
#   'park': 25,
#   'service': 4,
#   'defies': 3,
#   'social': 9,
#   'media': 8,
#   'ban': 14,
#   'tweets': 19,
#   'japanese': 1,
#   'interned': 1,
#   'during': 19,
#   'wwii': 1,
#   'httpstcoycnxxs1het': 1,
#   'danger': 7,
#   'zone': 3,
#   'httpstcotlw09drhlr': 1,
#   'anothergreen': 1,
#   'kurdish': 1,
#   'response': 5,
#   'httpstcolx19rqyelt': 1,
#   'httpstco46zdfm2vc2': 1,
#   'communicate': 6,
#   'officials': 12,
#   'risks': 37,
#   'change…': 68,
#   'httpstcoefmumrbqpt': 1,
#   'forces': 6,
#   'g20': 26,
#   'drop': 16,
#   'any': 19,
#   'mention': 13,
#   'joint': 7,
#   'statement': 11,
#   'httpstco49ee31typ7': 2,
#   'defense': 22,
#   'continues': 12,
#   'cleanenergy': 3,
#   'little': 9,
#   'httpstcovkjkdqukww': 1,
#   'quebec': 1,
#   'municipalities': 1,
#   'discuss': 36,
#   'montreal': 3,
#   'march': 18,
#   '23': 2,
#   'httpstcojjupla8x2s': 1,
#   'httpstcomzeekrqib3': 1,
#   'environmentguru': 1,
#   'stance': 16,
#   '…': 26,
#   'softening': 1,
#   'tone': 1,
#   'whether': 12,
#   'climate…': 5,
#   'httpstcobxf2iffncp': 1,
#   'climatechange…': 3,
#   'kill': 5,
#   'punxsutawney': 1,
#   'phil': 1,
#   'httpstco4bi9wetleb': 1,
#   'wwfaustralia': 1,
#   'nsw': 2,
#   'landclearing': 1,
#   'laws': 7,
#   'loss': 11,
#   'possingham': 1,
#   'httpstcoap1dcwlk5f': 1,
#   'radionational': 1,
#   'kids': 32,
#   'taking': 20,
#   'feds': 9,
#   'possibly': 9,
#   'court': 17,
#   'httpstcoogw21w7skw': 3,
#   'scientist': 37,
#   'spreads': 1,
#   'word': 2,
#   'biking': 1,
#   'across': 14,
#   'america': 19,
#   'wtop': 2,
#   'httpstcoobkp3pvtha': 1,
#   'ecolocyl': 1,
#   'epenvironment': 1,
#   'ceta': 1,
#   'contraries': 1,
#   'direction': 1,
#   'our': 21,
#   'commitments': 4,
#   'limit': 10,
#   'below': 2,
#   'temperature': 4,
#   '2°c': 2,
#   'cetat…': 1,
#   'creating': 7,
#   'void': 3,
#   'can': 68,
#   'persuade': 3,
#   'other': 14,
#   'help': 42,
#   'fill': 3,
#   'la': 3,
#   'httpstcol9zzs5ms6b': 1,
#   'featuremexicos': 1,
#   'maya': 2,
#   'point': 6,
#   'slow': 13,
#   'species': 18,
#   'httpstcoxhkkp2xgub': 1,
#   'googleaction': 1,
#   'harmful': 3,
#   'unnecessary': 1,
#   'car': 1,
#   'reports': 11,
#   'httpstcoso1v47qdxt': 1,
#   'heatwaves': 3,
#   'hurricanes': 6,
#   'floods': 18,
#   'famine': 4,
#   'seven': 3,
#   'hotspots': 4,
#   'httpstcohxjad92lex': 1,
#   'guardiannews': 7,
#   'httpstcowg2dfut3wd': 1,
#   'httpstcoly2ã¢â‚¬â¦': 1,
#   'minhazmerchant': 1,
#   'ministers': 3,
#   'italy': 5,
#   'pledge': 5,
#   'per': 5,
#   'accord': 10,
#   'without': 18,
#   'us…': 1,
#   'democracynow': 2,
#   'chomsky': 2,
#   'every': 10,
#   'republican': 13,
#   'candidate…': 1,
#   'either': 2,
#   'denied': 3,
#   'happening': 11,
#   'or…': 1,
#   'shouldnt': 1,
#   'a…': 3,
#   'pink3l3phants': 1,
#   'mayor': 11,
#   'chicago': 10,
#   'posted': 1,
#   'was': 31,
#   'off': 15,
#   'epas': 8,
#   'city…': 2,
#   'winenewz': 1,
#   'wine': 5,
#   'industry': 7,
#   'trouble': 2,
#   'httpstco1lerjnppmi': 1,
#   'really': 23,
#   'doesnt': 21,
#   'face': 21,
#   '21': 12,
#   'httpstcoohfhg9gz1o': 1,
#   'httpstcoexhofhe2kq': 1,
#   'aggyk': 1,
#   'five': 7,
#   'pacific': 11,
#   'islands': 7,
#   'lost': 11,
#   'rising': 6,
#   'seas': 5,
#   'hits': 7,
#   'httpstcokmnbmfandw': 1,
#   'nasa': 17,
#   'defiantly': 4,
#   'communicating': 3,
#   'despite': 44,
#   'trump’s': 63,
#   'httpstcoe3qtwwyv3z': 1,
#   'nasaclimate': 2,
#   'lift': 2,
#   '‘em': 1,
#   'y’all': 1,
#   'fusion': 3,
#   'peru': 5,
#   'suffering': 2,
#   'worst': 14,
#   'recent': 8,
#   'history—and': 2,
#   'some': 29,
#   'blame': 20,
#   'httpstco3egbsyvnjq': 1,
#   'environmentke': 1,
#   'kenya': 1,
#   'ratified': 2,
#   'judiwakhungu': 1,
#   'mygovke': 1,
#   'nemakenya': 1,
#   'keforestservice…': 1,
#   'professors': 2,
#   'sign': 25,
#   'open': 9,
#   'letter': 9,
#   'urging': 8,
#   'httpstcozqbytitw7n': 1,
#   'httpstcoba…': 1,
#   'aireguru': 1,
#   'knocks': 2,
#   'extends': 3,
#   'effort': 9,
#   'ap': 20,
#   'gov…': 1,
#   'httpstcoepbsdmntt1…': 1,
#   'causes': 24,
#   'uproar': 10,
#   'contradicts': 14,
#   'epa’s': 14,
#   'washington': 34,
#   'post': 30,
#   'httpstcotwyznb4dev': 1,
#   'huffpostpol': 18,
#   'wildlife': 8,
#   'far': 6,
#   'worse': 19,
#   'than': 45,
#   'thought': 10,
#   'httpstcowtj7f15pez': 1,
#   'australia': 23,
#   'being': 30,
#   'left': 10,
#   'behind': 9,
#   'momentum': 5,
#   'httpstcowscqtag2qv': 1,
#   'appointees': 1,
#   'fake': 6,
#   'big': 10,
#   'httpstcotikadhbalj': 1,
#   'pattern': 4,
#   'cloud': 3,
#   'cover': 4,
#   'masked': 3,
#   'thereã¢â‚¬â„¢s': 2,
#   'deceptively': 2,
#   'simple': 4,
#   'number': 4,
#   'httpstcob2u5ucfrjk': 1,
#   'enters': 5,
#   'into': 64,
#   'httpstcojjtou0jtlj': 1,
#   'articles': 5,
#   'last': 14,
#   '48': 1,
#   'hrs': 2,
#   'httpstcodnwnm9egn0': 1,
#   'memo': 5,
#   'alarms': 5,
#   'energy': 100,
#   'staff': 16,
#   'cnbc': 8,
#   'httpstcoe7ummzsp67': 1,
#   'pennsylvania': 1,
#   'fracking': 2,
#   'clash': 2,
#   'httpstcoyelndnzwd1': 1,
#   'attorney': 10,
#   'general': 15,
#   'japan': 3,
#   'times…': 2,
#   'httpstcornme3ciw1p': 1,
#   'pruitt’s': 14,
#   'office': 26,
#   'deluged': 16,
#   'angry': 16,
#   'callers': 16,
#   'questions': 24,
#   'warming…': 12,
#   'httpstcooskpqxs884': 1,
#   'ajenglish': 8,
#   'worldpenguinday': 2,
#   'this': 34,
#   'penguin': 2,
#   'colony': 2,
#   'httpstcoibmsbissbx': 3,
#   'meeting': 20,
#   'urges': 35,
#   'highest': 3,
#   'political': 9,
#   'afp': 3,
#   'reindeer': 10,
#   'disappearing': 7,
#   'alarming': 3,
#   'rate': 2,
#   'alaska': 7,
#   'httpstcoefbsqqhkwg': 1,
#   'obama': 76,
#   'admin': 10,
#   'sending': 3,
#   '500': 1,
#   'million': 18,
#   'fund': 23,
#   'httpstcozqjq44gnbv': 1,
#   'tongotongoz': 1,
#   'lastnightinsweden': 1,
#   'mass': 5,
#   'immigration': 2,
#   'north': 5,
#   'httpstcofj8nmlkrep': 1,
#   'wef': 11,
#   'cities': 29,
#   'outpacing': 2,
#   'race': 14,
#   'curb': 31,
#   'httpstcos7gqg2epsp': 1,
#   'httpstcok9xtl6jozc': 1,
#   'nbc': 1,
#   'dismissed': 2,
#   'manmade': 8,
#   'httpstcod5ijbhxjit': 1,
#   'httpstcokhoscaoboa': 1,
#   'many': 9,
#   'young': 6,
#   'poverty': 5,
#   'much': 18,
#   'terrorism': 5,
#   'httpstcopahvdxjyv2': 1,
#   'httpstcofo6ja1nqen': 1,
#   'thebaxterbean': 1,
#   'executive': 42,
#   'order': 64,
#   'dismantling': 4,
#   'president': 100,
#   'combat': 29,
#   'barack': 7,
#   'create': 3,
#   'refugee': 2,
#   'crisis': 8,
#   '‘unprecedented': 2,
#   'human': 29,
#   'history’…': 1,
#   'clintonkowach': 1,
#   'ethiopias': 2,
#   'coffee': 5,
#   'httpstcouhp73q7apg': 1,
#   ...},
#  0: {'calum': 2,
#   'tweets': 5,
#   'abt': 5,
#   'reunitingish': 1,
#   'w': 13,
#   'the': 946,
#   'cast': 1,
#   'sees': 1,
#   'replies': 1,
#   'begging': 1,
#   'him': 19,
#   'to': 747,
#   'come': 25,
#   'their': 26,
#   'countries': 7,
#   'goes': 4,
#   'back': 21,
#   'rting': 1,
#   'climate': 1437,
#   'change': 1370,
#   'we': 157,
#   'also': 24,
#   'met': 7,
#   'this': 217,
#   'guy': 11,
#   'he': 94,
#   'let': 6,
#   'us': 101,
#   'in': 428,
#   'on': 425,
#   'some': 32,
#   'truth': 7,
#   'about': 324,
#   'and': 447,
#   'gay': 5,
#   'people': 65,
#   'not': 160,
#   'existing': 1,
#   'httpstcoq7yomcmzaj': 1,
#   'jnpftw': 1,
#   'are': 184,
#   'these': 23,
#   'same': 16,
#   'scientists': 24,
#   'that': 263,
#   'denounce': 3,
#   'its': 130,
#   'a': 564,
#   'choice': 4,
#   'we’': 1,
#   've': 1,
#   'dealt': 1,
#   'with': 179,
#   'simple': 5,
#   'issues': 11,
#   'like': 96,
#   'energy': 24,
#   'policy': 15,
#   'now': 84,
#   'complex': 5,
#   'mal': 2,
#   'vs': 4,
#   'tones': 2,
#   'qanda': 5,
#   'rt': 1091,
#   'andrewsharp': 1,
#   'win': 5,
#   'probability': 1,
#   'is': 592,
#   'bullshit': 5,
#   'man': 30,
#   'i': 352,
#   'saw': 5,
#   'nba': 1,
#   'finals': 1,
#   'thats': 36,
#   'when': 70,
#   'knew': 1,
#   'global': 1035,
#   'warming': 981,
#   'isnt': 57,
#   'real': 98,
#   'chris': 1,
#   'who': 56,
#   'it': 193,
#   'then': 57,
#   'initially': 1,
#   'talked': 8,
#   'me': 107,
#   'thinked': 1,
#   'for': 303,
#   'three': 2,
#   'seconds': 2,
#   'europeaã¢â‚¬â¦': 1,
#   'httpstcovwlqicy0h0': 1,
#   'do': 152,
#   'you': 336,
#   'approve': 1,
#   'of': 455,
#   'executive': 4,
#   'order': 6,
#   'realdonaldtrump': 31,
#   'due': 21,
#   'sign': 7,
#   're': 6,
#   'environment': 12,
#   'httpstconr6nqbjl5m': 1,
#   'glennf': 1,
#   'they': 96,
#   'calling': 3,
#   'great': 36,
#   'space': 6,
#   'cylinder': 1,
#   'save': 7,
#   'them': 26,
#   'from': 112,
#   'fuckofflaine': 1,
#   'jjxrry': 1,
#   'spacex': 1,
#   'quebanjesus': 1,
#   'antarctica': 4,
#   'so': 133,
#   'big': 17,
#   'lmao': 5,
#   'how': 138,
#   'nigga': 5,
#   'just': 94,
#   'use': 12,
#   'an': 64,
#   'air': 18,
#   'conditioner': 1,
#   'hope012015': 1,
#   'china': 26,
#   'tells': 4,
#   'trump': 153,
#   'hoax': 30,
#   'invented': 3,
#   'httpstcotx06pzxyzd': 1,
#   'via': 24,
#   'business': 7,
#   'lol': 21,
#   'schooling': 2,
#   'tã¢â‚¬â¦': 6,
#   'uscgpacificnw': 1,
#   'nsf': 1,
#   'icebreaking': 1,
#   'ships': 1,
#   'primary': 5,
#   'cause': 55,
#   'arctic': 7,
#   'freeze': 4,
#   'over': 36,
#   'amp': 100,
#   'stay': 5,
#   'away': 11,
#   'there': 41,
#   'if': 173,
#   'doesnt': 53,
#   'exist': 19,
#   'why': 92,
#   'club': 44,
#   'penguin': 84,
#   'shutting': 20,
#   'down': 56,
#   'httpstco1os6c8mfyx': 1,
#   'cernovich': 4,
#   'httpstcofecivoogma': 1,
#   'ldnenvironment': 1,
#   'weve': 3,
#   'few': 5,
#   'short': 8,
#   'term': 6,
#   'opps': 1,
#   'working': 5,
#   'send': 5,
#   'your': 85,
#   'cv': 1,
#   'or': 74,
#   'qs': 1,
#   'environmentlondongovuk': 1,
#   'h…': 7,
#   'markbaileymp': 1,
#   'fed': 1,
#   'energyenvt': 1,
#   'minister': 2,
#   'joshfrydenberg': 2,
#   'refused': 1,
#   'allow': 7,
#   'coag': 1,
#   'council': 3,
#   'communique': 1,
#   'despit…': 1,
#   'jadorelacouture': 1,
#   'fact': 12,
#   'leonardo': 30,
#   'dicaprio': 20,
#   'discuss': 10,
#   'smithsonianenv': 1,
#   'sercs': 1,
#   'roy': 1,
#   'rich': 2,
#   'colleagues': 1,
#   'create': 3,
#   'buzz': 1,
#   'germany': 1,
#   'simulation': 1,
#   'httpstcoy6shqnjexh…': 1,
#   'senior': 3,
#   'quality': 3,
#   'specialist': 1,
#   'as': 93,
#   'air…': 1,
#   'httpstcotsqzmjwlh9': 1,
#   'airquality': 1,
#   'climatechange': 15,
#   'greenhousegas': 1,
#   'cnn': 18,
#   'protest': 3,
#   'against': 14,
#   'stupid': 8,
#   'm3thg0d': 1,
#   'did': 43,
#   'shut': 21,
#   'prisonplanet': 2,
#   'wow': 11,
#   'finally': 5,
#   'evil': 3,
#   'wake': 1,
#   'up': 62,
#   'good': 39,
#   'drishtiias': 1,
#   'audio': 2,
#   'article': 15,
#   '25environment': 1,
#   '02': 1,
#   'after': 30,
#   'trumps': 22,
#   'decision': 3,
#   'what': 158,
#   'will': 114,
#   'be': 141,
#   'form': 6,
#   'paris': 18,
#   'agreement': 16,
#   'https…': 25,
#   'politicalshort': 1,
#   'piewagn': 1,
#   'dems': 2,
#   'causing': 21,
#   'stfu': 1,
#   'reader': 1,
#   'questions': 7,
#   'science': 29,
#   'theories': 3,
#   'httpstco1zeco8bwiv': 1,
#   'zachheltzel': 1,
#   'believe': 87,
#   'generally': 1,
#   'refuse': 1,
#   'say': 33,
#   'trans': 2,
#   'out': 64,
#   'loud': 1,
#   'youre': 15,
#   'no': 73,
#   'better': 9,
#   'vp': 3,
#   'nasajohnson': 1,
#   'ask': 21,
#   'explain': 16,
#   'jinjjarevil': 1,
#   'way': 20,
#   'seokjin': 1,
#   'blinks': 1,
#   'adorable': 1,
#   'stops': 1,
#   'trees': 3,
#   'grow': 1,
#   'crime': 22,
#   'rate': 4,
#   'decreases': 1,
#   'httpstcotz5a5alrva': 1,
#   'benhulac': 1,
#   'asked': 33,
#   'charges': 1,
#   'exxonmobil': 1,
#   'withheld': 1,
#   'information': 4,
#   'tillerson': 5,
#   'declines': 1,
#   'answer': 9,
#   'twice': 1,
#   'secretaryofst…': 1,
#   'rjsalmond': 1,
#   'was': 95,
#   'already': 10,
#   'denial': 9,
#   'but': 114,
#   'either': 10,
#   'above': 1,
#   'would': 43,
#   'which': 26,
#   'my': 134,
#   'loss': 6,
#   'well': 26,
#   'quiz': 2,
#   'cultural': 2,
#   'heritageclimate': 1,
#   'disclaimer': 1,
#   'dont': 71,
#   'agree': 6,
#   'all': 130,
#   'answers': 6,
#   'still': 37,
#   'interesting': 20,
#   'httpstco4jejnwgnxq': 1,
#   'look': 24,
#   'whos': 5,
#   'town': 2,
#   'thank': 13,
#   'ã¢â‚¬â€œ': 2,
#   'enjoying': 4,
#   'quick': 6,
#   'trip': 3,
#   'brown': 2,
#   'county': 1,
#   'state': 5,
#   'park': 4,
#   '75': 1,
#   'degree': 4,
#   'november': 14,
#   'day': 25,
#   'puffnpuffin': 1,
#   'stevemartintogo': 1,
#   'billnye': 5,
#   'bumfonline': 1,
#   'could': 25,
#   'someone': 14,
#   'link': 7,
#   'journal': 3,
#   'his': 44,
#   'reviewed': 3,
#   'one': 49,
#   'guess': 13,
#   'have': 101,
#   'mei': 1,
#   'mains': 1,
#   'jackposobiec': 3,
#   'soon': 10,
#   'altright': 1,
#   'blamed': 7,
#   'gingivitis': 1,
#   'httpstco6cdurfapse': 1,
#   'senatormroberts': 2,
#   'much': 32,
#   'finkel': 1,
#   'blueprint': 1,
#   'stop': 31,
#   'by': 106,
#   '2100': 2,
#   'none': 4,
#   'deindustrialise': 1,
#   'our': 44,
#   'economy': 9,
#   'fo…': 1,
#   'prisionplaneta': 1,
#   'scottadamssays': 5,
#   'studies': 4,
#   'only': 32,
#   'choose': 2,
#   'show': 14,
#   'ones': 3,
#   'htt…': 4,
#   'inspiration': 20,
#   'told': 25,
#   'em': 8,
#   'warming😂🔥🌎❄️': 1,
#   'think': 81,
#   'solved': 6,
#   'problem': 13,
#   'kids': 9,
#   'fix': 12,
#   'sit': 3,
#   'wait': 12,
#   'dadlife': 1,
#   'tell': 31,
#   'story': 10,
#   'contest': 1,
#   'httpstcofkiou2nb9f': 1,
#   'httpstcoyz9j4mlyba': 1,
#   'petraau': 1,
#   'more': 86,
#   'than': 47,
#   '190': 2,
#   'subtweeted': 2,
#   'httpstcon5x8yj4uln': 1,
#   'lianamaeby': 1,
#   'plus': 2,
#   'side': 7,
#   'anymore': 5,
#   'robydalvik': 1,
#   'kalem2': 1,
#   'ini': 2,
#   'karena': 5,
#   'faktor': 1,
#   'laut': 1,
#   'naik': 2,
#   'conversation': 4,
#   'go': 13,
#   'morning': 5,
#   'arthur': 2,
#   'cold': 26,
#   'yes': 25,
#   'obviously': 5,
#   'fake': 14,
#   'agreed': 2,
#   'thi…': 1,
#   'httpstcodzlrwoyudx': 1,
#   'caused': 22,
#   'her': 26,
#   'cabbage': 1,
#   'farts': 4,
#   'simonwest26': 1,
#   'brilliant': 1,
#   'cartoon': 3,
#   'sums': 2,
#   'cancel': 16,
#   'barackobama': 1,
#   'policies': 10,
#   'itisreal…': 1,
#   'adam': 1,
#   'adamcurry': 1,
#   'maakte': 1,
#   'al': 14,
#   '923': 1,
#   'keer': 1,
#   'zijn': 2,
#   'agenda': 8,
#   'httpstcolnxz3ymwx7': 1,
#   'leuk': 1,
#   'info': 3,
#   'warming…': 8,
#   'httpstcorfj97wh8j2': 1,
#   'erry': 1,
#   'reason': 11,
#   'fight': 19,
#   'httpstco1us1pjn0jk': 1,
#   'ccol': 1,
#   'httpstcowhgeltfatx': 1,
#   'can': 91,
#   'putting': 3,
#   'ac': 1,
#   'outside': 13,
#   'ineed2takeatwit': 1,
#   'zwash300': 1,
#   'foxnews': 9,
#   'thejuanwilliams': 1,
#   'lolololololol': 1,
#   'oceans': 1,
#   'rising': 6,
#   'even': 33,
#   'without': 7,
#   'change…': 15,
#   'httpstcouhgj4g9iq4': 1,
#   'stand': 3,
#   'successes': 2,
#   'hayleiip': 1,
#   'im': 81,
#   'qualified': 1,
#   'pulled': 2,
#   'pic': 5,
#   'environmental': 4,
#   'ni…': 1,
#   'wingsscotland': 2,
#   'belfast': 1,
#   'alone': 2,
#   'probably': 13,
#   'accelerates': 2,
#   'year': 19,
#   'night': 8,
#   'httpstcobiie3czgg5': 1,
#   'dicapriofdn': 1,
#   'u': 28,
#   'preach': 1,
#   'yacht': 1,
#   'hypocrite': 6,
#   'gesemdicapt': 1,
#   'fuck': 21,
#   'anyone': 9,
#   'lives': 7,
#   'earth': 17,
#   'laughing': 1,
#   'at': 79,
#   'because': 50,
#   'httpstcow9tuynzyhw': 1,
#   'mattis': 3,
#   'says': 45,
#   'proves': 3,
#   'elections': 1,
#   'httpstcowkexdzq33k': 1,
#   'henningakesson': 1,
#   'interested': 5,
#   'glaciers': 4,
#   '2yr': 1,
#   'researcher': 2,
#   'position': 6,
#   'regional': 1,
#   'modeling': 3,
#   'bjerknesbccr': 1,
#   'uib': 1,
#   'right': 37,
#   'significant': 2,
#   'weather': 36,
#   'event': 6,
#   'blindly': 1,
#   'blame': 20,
#   'tahjshaunx': 1,
#   'funnymaine': 1,
#   'black': 8,
#   'men': 5,
#   'hitlers': 1,
#   'main': 8,
#   'target': 1,
#   'holocaust': 1,
#   'women': 9,
#   'amcp': 3,
#   'papers': 3,
#   'crid485fxj': 1,
#   'has': 63,
#   'isolated': 1,
#   'himself': 2,
#   'completely': 1,
#   'elliehighwood': 1,
#   'ok': 8,
#   'am': 17,
#   'crochet': 1,
#   'addict': 1,
#   'blanket': 1,
#   'stripes': 1,
#   'coloured': 1,
#   'according': 5,
#   'last': 13,
#   '100': 6,
#   'years': 19,
#   't': 3,
#   'an…': 2,
#   'cudder': 1,
#   'everyone': 19,
#   '3pointedit': 1,
#   'triggers': 1,
#   'rise': 10,
#   'giant': 4,
#   'orchids': 1,
#   'battle': 3,
#   'carniverous': 1,
#   'plants': 1,
#   'devour': 1,
#   'dwindling': 1,
#   'humans': 12,
#   'thefilm': 1,
#   'bringing': 5,
#   'tornadoes': 2,
#   'floods': 2,
#   'god': 11,
#   'america': 9,
#   'plaguing': 1,
#   'farrakhan': 1,
#   'quote': 2,
#   'nuclear': 22,
#   'war': 10,
#   'might': 15,
#   'plunge': 1,
#   'into': 28,
#   'winter': 23,
#   'wont': 12,
#   'worry': 7,
#   'notlinkolafan': 1,
#   'httpstco41xbjndvnm': 1,
#   'rowanjones': 1,
#   'need': 37,
#   'pay': 7,
#   'kimkardashian': 1,
#   'heaps': 1,
#   'cash': 3,
#   'promote': 1,
#   'solutions': 3,
#   'lets': 7,
#   'httpstã¢â‚¬â¦': 10,
#   'boredeaths': 1,
#   'mtthwdvs': 1,
#   'hope': 6,
#   '2017': 5,
#   'learn': 1,
#   'difference': 5,
#   'between': 19,
#   'shellenbergermd': 1,
#   'new': 44,
#   'leodicaprio': 7,
#   'web': 1,
#   'site': 2,
#   'attacks': 1,
#   'power': 7,
#   'while': 14,
#   'plant': 5,
#   'closures': 1,
#   'increase': 3,
#   'co2': 8,
#   'emissions': 7,
#   'htã¢â‚¬â¦': 1,
#   'grandma': 1,
#   'said': 44,
#   'she': 18,
#   'aveeuropathe2nd': 1,
#   'pb4p': 1,
#   'cling': 1,
#   'idea': 7,
#   'having': 11,
#   'anything': 12,
#   'civil': 4,
#   'rights': 13,
#   'website': 7,
#   'plesscatherine': 1,
#   'team': 5,
#   'energyclimate': 1,
#   'should': 36,
#   'check': 6,
#   'mcggovt': 1,
#   'mariamartmcg': 1,
#   'cocodupepe1': 1,
#   'marlapeyre': 1,
#   'eliseffant': 1,
#   'httpsã¢â‚¬â¦': 19,
#   'pollreport': 1,
#   'address': 5,
#   'doing': 12,
#   'enough': 9,
#   '18': 1,
#   'too': 29,
#   '19': 3,
#   'needs': 9,
#   '59': 1,
#   'quinnipiac': 2,
#   'rv': 1,
#   '326': 1,
#   'ezralevant': 5,
#   'sheilagunnreids': 2,
#   'videos': 3,
#   'un': 23,
#   'conference': 19,
#   'marrakech': 2,
#   'comeã¢â‚¬â¦': 2,
#   'weathernetwork': 1,
#   'snow': 19,
#   'joke': 6,
#   'claims': 5,
#   'yet': 8,
#   'another': 9,
#   'casualty': 1,
#   'saveoursnowmen': 1,
#   'httpstco5ttjkcopeq': 1,
#   'httpstcoou4mkv…': 1,
#   'thenextweb': 2,
#   'national': 15,
#   'geographicã¢â‚¬â„¢s': 4,
#   'documentary': 23,
#   'youtube': 10,
#   'httpstcoqmsxaykcjo': 1,
#   'ultravlolence': 20,
#   'interviewer': 21,
#   'melania': 22,
#   'hello': 23,
#   'hes': 77,
#   'kind': 24,
#   'strong': 21,
#   'cã¢â‚¬â¦': 21,
#   'nuritben': 1,
#   'world': 41,
#   'ranges': 1,
#   'different': 3,
#   'eural': 1,
#   'india': 3,
#   'africa': 3,
#   'jedrlee': 8,
#   'hey': 17,
#   'girl': 9,
#   'going': 36,
#   'ignore': 10,
#   'until': 15,
#   'denying': 7,
#   'celebrate': 2,
#   'overcome': 1,
#   'obamacare': 4,
#   '20': 3,
#   'million': 4,
#   'becketadams': 3,
#   'journo': 1,
#   'twitter': 11,
#   'seems': 3,
#   'angrier': 1,
#   'bret': 4,
#   'stephens’': 1,
#   'oped': 3,
#   'week': 11,
#   'nyt': 13,
#   'publish…': 1,
#   'drshow': 1,
#   'amyaharder': 3,
#   'chriscmooney': 1,
#   'surveyfunk': 1,
#   'project': 4,
#   '30': 3,
#   '1': 14,
#   'kfb9999': 1,
#   'maybe': 22,
#   'messing': 2,
#   'sleep': 2,
#   'cycle': 1,
#   'cuntpanda': 1,
#   'globetoppers': 1,
#   'rickagain': 1,
#   'mercnews': 1,
#   'cartoons': 1,
#   'donald': 19,
#   'httpstcom4ttxr85ss': 1,
#   'httpstcokrwcn0hxpz': 1,
#   'kejayurbane': 1,
#   'humid': 2,
#   'hot': 52,
#   'thot': 3,
#   'kejay': 1,
#   'urbane': 1,
#   'mood': 2,
#   'piece': 3,
#   'yay': 1,
#   'thing': 39,
#   'concerns': 1,
#   'please': 18,
#   'those': 12,
#   'boys': 6,
#   'deny': 9,
#   'get': 46,
#   'biã¢â‚¬â¦': 1,
#   'httpstcomhh7o88ytp': 1,
#   'gabrielgrims': 1,
#   'habitat': 1,
#   'driving': 1,
#   'species': 4,
#   'extinction': 4,
#   'crisis': 4,
#   'httpstcop6m9kuplha': 1,
#   'realpeerreview': 1,
#   'resurgence': 1,
#   'dragons': 2,
#   'httpstcoyyjwtqlkdg': 1,
#   'httpstcolfi0wi8as0': 1,
#   'catalyticrxn': 1,
#   'trend': 4,
#   'toward': 2,
#   'increased': 3,
#   'acceptance': 3,
#   'humancaused': 4,
#   'flat': 2,
#   'science2016electiã¢â‚¬â¦': 1,
#   'catbeltane': 2,
#   'cool': 10,
#   '0': 5,
#   '3': 7,
#   'presidential': 3,
#   'debates': 7,
#   'featured': 2,
#   'any': 21,
#   'whatsoever': 2,
#   'httpstcogkã¢â‚¬â¦': 2,
#   'repstevensmith': 3,
#   'host': 3,
#   'vote': 8,
#   'hillary': 12,
#   'believes': 15,
#   'make': 30,
#   'actually': 20,
#   'warfare': 1,
#   'hoosierworld': 1,
#   'entertainers': 1,
#   'theyre': 16,
#   'meeting': 7,
#   'lib': 1,
#   'presidents': 1,
#   'work': 13,
#   'dare': 2,
#   'talk': 33,
#   'urban…': 1,
#   'classylikekoi': 1,
#   'justinkanew': 1,
#   'keep': 15,
#   'heard': 12,
#   'something': 14,
#   'weeks': 6,
#   'ago': 9,
#   'infothey': 1,
#   'taking': 7,
#   'kid': 3,
#   'named': 3,
#   'naomi': 1,
#   'started': 13,
#   'damn': 14,
#   'mike': 3,
#   'drop': 3,
#   'little': 9,
#   '6': 5,
#   'yo': 5,
#   'question': 10,
#   'amitav': 1,
#   'ghosh': 1,
#   'talks': 8,
#   'book': 8,
# ...
#   'tax': 31,
#   'globalist': 4,
#   'idea': 5,
#   'to': 478,
#   'enslave': 1,
#   'the': 844,
#   'worlds': 4,
#   'population': 2,
#   'it': 158,
#   'whole': 7,
#   'reason': 6,
#   'for': 183,
#   'propagating': 2,
#   'global': 632,
#   'warming': 597,
#   'rt': 684,
#   'stevesgoddard': 44,
#   'had': 13,
#   'winds': 1,
#   'close': 3,
#   '100': 7,
#   'mph': 1,
#   'in': 236,
#   'area': 3,
#   'this': 108,
#   'afternoon': 2,
#   'i': 120,
#   'would': 50,
#   'blame': 17,
#   'except': 4,
#   'that': 160,
#   'happens': 4,
#   'pr…': 2,
#   'misslizzynj': 4,
#   'lmao': 4,
#   '😂': 2,
#   'snowflakes': 11,
#   '❄️': 2,
#   'complaining': 2,
#   'about': 166,
#   'winter': 6,
#   '🤦\u200d♂️': 1,
#   'dawn2334dawn': 1,
#   'one': 33,
#   'arnold': 1,
#   'schwarzeneggers': 1,
#   'vehicles': 1,
#   'he': 36,
#   'now': 57,
#   'whining': 1,
#   'hows': 1,
#   'his': 24,
#   'maidillegal': 1,
#   'or': 42,
#   'http…': 6,
#   'fruitloopian': 1,
#   'why': 39,
#   'there': 53,
#   'snow': 16,
#   'march': 8,
#   'if': 71,
#   'have': 79,
#   'can': 38,
#   'someone': 6,
#   'pls': 2,
#   'explain': 12,
#   'me': 23,
#   'its': 115,
#   '37': 1,
#   'who': 67,
#   'my': 29,
#   'advocates': 2,
#   'httpstcowpkndebunw': 1,
#   'tomilahren': 4,
#   'kinda': 2,
#   'funny': 6,
#   'professors': 1,
#   'talk': 6,
#   'shit': 11,
#   'trumpstersomg': 1,
#   'f': 1,
#   'them': 11,
#   'scientist': 28,
#   'trumpserst': 1,
#   'idots': 1,
#   'shows': 5,
#   'base🤔': 1,
#   'signordal': 1,
#   'new': 22,
#   'study': 9,
#   'terrible': 2,
#   'news': 35,
#   'alarmists': 21,
#   'good': 28,
#   'plants': 3,
#   'animals': 3,
#   'anhttpstcokgjxlvfs7a': 1,
#   'https…': 24,
#   'cbsnews': 1,
#   'youre': 12,
#   'not': 123,
#   'going': 28,
#   'get': 25,
#   'away': 10,
#   'with': 79,
#   'are': 128,
#   'call': 14,
#   'you': 168,
#   'out': 32,
#   'every': 12,
#   'single': 4,
#   'time': 24,
#   'all': 96,
#   'pages': 2,
#   'gone': 1,
#   'inc': 1,
#   'fake': 36,
#   'charliedaniels': 2,
#   'im': 20,
#   'worried': 11,
#   'but': 77,
#   'terrified': 2,
#   'government': 9,
#   'hoax': 50,
#   'perpetrated': 3,
#   'by': 131,
#   'chinese': 31,
#   'carbongate': 7,
#   'physicist': 3,
#   'co2': 20,
#   'does': 17,
#   'cause': 33,
#   'responds': 3,
#   'video': 6,
#   'httpstcolyszb7gclh': 1,
#   'agreed': 1,
#   'manmade': 47,
#   'innit': 1,
#   'httpstco4nbikg6tdz': 1,
#   'tamorley': 1,
#   'zekejmiller': 1,
#   'isnt': 27,
#   'stuff': 2,
#   'hokum': 1,
#   'mikebeacham': 1,
#   'fed': 2,
#   'cooked': 8,
#   'books': 7,
#   'ahead': 5,
#   'obama': 40,
#   'presentation': 4,
#   'nomorescams': 1,
#   'nomoredemocrats': 1,
#   'draintheswamp': 1,
#   'countermoonbat': 16,
#   'people': 56,
#   'predicted': 16,
#   'parts': 14,
#   'manhattan': 13,
#   'be': 97,
#   'underwater': 13,
#   '2008': 14,
#   'due': 27,
#   'concerned': 17,
#   'fakeã¢â‚¬â¦': 12,
#   'zrastall17': 1,
#   'fakenews': 3,
#   'mrbrexit': 1,
#   'looking': 3,
#   'ditch': 1,
#   'paris': 13,
#   'agreement': 7,
#   'and': 217,
#   'bust': 2,
#   'open': 5,
#   'myth': 19,
#   'maga': 13,
#   'stepfoã¢â‚¬â¦': 1,
#   'was': 83,
#   'thinking': 3,
#   'same': 22,
#   'thing': 15,
#   'goes': 5,
#   'when': 49,
#   'other': 16,
#   'important': 11,
#   'issues': 4,
#   'effect': 3,
#   'amer…': 1,
#   'httpstcohh1dotqkhs': 1,
#   'uniocracy': 3,
#   'theyll': 6,
#   'tell': 15,
#   'theyre': 7,
#   'doing': 4,
#   'save': 9,
#   'from': 57,
#   'lying': 8,
#   'httpstcoprfpim7pyj': 1,
#   'opchemtrails': 7,
#   'newsfakenews': 1,
#   'todd': 2,
#   'starnes': 2,
#   'hey': 11,
#   'npr': 2,
#   '—': 4,
#   'take': 14,
#   'your': 42,
#   'nonsense': 6,
#   'kids': 9,
#   'blow': 3,
#   'f150': 2,
#   'tailpipe': 1,
#   'httpstcoc4v…': 1,
#   'nobamadotcom': 1,
#   'libbyrafferty': 1,
#   'bizpacreview': 2,
#   'how': 58,
#   'left': 28,
#   'scream': 1,
#   'their': 29,
#   'allegiance': 1,
#   'science': 75,
#   'on': 162,
#   'issue': 11,
#   'concept': 26,
#   'created': 28,
#   'order': 27,
#   'make': 42,
#   'us': 62,
#   'manufacturing': 25,
#   'noncompetitive': 23,
#   'natural': 15,
#   'wins': 1,
#   '10': 6,
#   '0': 1,
#   'httpstcoa1ap0wiv1q': 2,
#   'harmlessyarddog': 1,
#   '21': 1,
#   'aged': 1,
#   '9': 3,
#   '20': 10,
#   'suing': 2,
#   'trump': 60,
#   'over': 38,
#   '������': 1,
#   'gtleftist': 1,
#   'disease': 1,
#   'httpstcogdfhouik1e': 1,
#   'selling': 2,
#   'as': 62,
#   'scientific': 17,
#   'vs': 2,
#   'governments': 1,
#   'control': 14,
#   'everything': 11,
#   'terrifying': 1,
#   'public': 1,
#   'earthday…': 1,
#   'httpstcoazuv4imtcv': 1,
#   'sallykohn': 1,
#   'related': 1,
#   'part': 8,
#   'larger': 1,
#   'pattern': 1,
#   'doesnt': 20,
#   'prove': 8,
#   'q': 1,
#   'much': 17,
#   'do': 52,
#   'affect': 1,
#   'randomsavage3': 1,
#   'frmatthewlc': 1,
#   'crazy': 7,
#   'two': 6,
#   'days': 5,
#   'ago': 12,
#   'were': 30,
#   'bezerk': 1,
#   'then': 22,
#   'blizzard': 4,
#   'hits': 3,
#   'katieworth': 1,
#   'story': 7,
#   'campaign': 1,
#   'persuade': 1,
#   'teacher': 1,
#   'debatable': 1,
#   'frontlinepbs': 1,
#   'just': 66,
#   'evolution': 1,
#   'planet': 7,
#   'so': 71,
#   'upset': 3,
#   'try': 5,
#   'stop': 26,
#   'albertstienstra': 1,
#   'climaterealists': 3,
#   'almost': 3,
#   'democrat': 2,
#   'vote': 2,
#   'very': 11,
#   'young': 3,
#   'caused': 26,
#   'scaremongering': 1,
#   'indoctã¢â‚¬â¦': 1,
#   'revkin1': 1,
#   'got': 11,
#   'point': 9,
#   'still': 16,
#   'stupid': 5,
#   'absurd': 1,
#   'tornado': 1,
#   'hurricane': 4,
#   'etc': 5,
#   'result': 2,
#   'man': 53,
#   'made': 47,
#   'danieljhannan': 2,
#   'accept': 4,
#   'consensus': 6,
#   'often': 3,
#   'dismiss': 2,
#   'frackin…': 1,
#   'tuckercarlson': 8,
#   'forget': 3,
#   'poverty': 3,
#   'exploding': 2,
#   'crime': 3,
#   'rate': 2,
#   'mayor': 4,
#   'orleans': 2,
#   'making': 14,
#   'top': 9,
#   'priorit…': 1,
#   'jwilla': 1,
#   'sethmacfarlane': 2,
#   'real': 63,
#   'name': 6,
#   'weather': 28,
#   'changes': 5,
#   'naturally': 3,
#   'hope': 8,
#   'they': 72,
#   'chance': 2,
#   'skip': 1,
#   'httpstcomv7jduohie': 1,
#   'prisonplanet': 20,
#   'bunch': 10,
#   'oxford': 9,
#   'elitists': 9,
#   'want': 21,
#   'food': 11,
#   'poor': 11,
#   'because': 40,
#   'fuck': 14,
#   'off': 22,
#   'instead': 14,
#   'httpã¢â‚¬â¦': 13,
#   'dineshdsouza': 7,
#   'thought': 8,
#   'day': 18,
#   'gender': 5,
#   'social': 1,
#   'constructwhich': 1,
#   'head': 7,
#   'maybe': 8,
#   'too': 11,
#   'climatetruthnow': 2,
#   'george': 5,
#   'clooney': 2,
#   'claims': 11,
#   'must': 16,
#   'exist': 3,
#   'liberals': 30,
#   'agree': 11,
#   'exists': 5,
#   'httpstco5kbjã¢â‚¬â¦': 1,
#   'kellyhinestw': 1,
#   'cold': 12,
#   'tulsa': 1,
#   'mich': 1,
#   'will': 55,
#   'cool': 4,
#   'down': 15,
#   'place': 3,
#   'miamibeachbowl': 1,
#   'bikerdave100': 1,
#   'question': 11,
#   'al': 36,
#   'gore': 40,
#   'hell': 25,
#   'denier': 9,
#   'dispatch': 1,
#   'httpstco9ckmf56s32': 1,
#   'c…': 7,
#   'fraud': 21,
#   'refuses': 5,
#   'debate': 8,
#   'httpstcop9r5arlcmw': 1,
#   'usfreedomarmy': 9,
#   'understand': 5,
#   'globalism': 2,
#   'amp': 83,
#   'enlist': 13,
#   'gt': 2,
#   'httpstcoospey48noh': 2,
#   'act': 3,
#   'april': 5,
#   'yeah': 5,
#   'freezing': 17,
#   'outside': 21,
#   'where': 27,
#   'generaleeintuit': 1,
#   'dcexaminer': 1,
#   'weathermen': 1,
#   'cant': 15,
#   'tomorrows': 2,
#   'right': 14,
#   'based': 5,
#   'data': 45,
#   'predict': 1,
#   '2…': 1,
#   'brentbozell': 2,
#   'rewrite': 1,
#   'history': 7,
#   'fit': 2,
#   'agenda': 18,
#   'journalist': 1,
#   'propagandist': 2,
#   'httpstcot6s7…': 1,
#   'hrkbenowen': 5,
#   'horror': 3,
#   'chelsea': 2,
#   'clinton': 4,
#   'blames': 11,
#   'diabetes': 2,
#   'gets': 8,
#   'factchecked': 2,
#   'hard': 6,
#   'httpstcoe2ue5nvhoa': 1,
#   'york': 4,
#   'times': 8,
#   'slammed': 1,
#   'cancellations': 1,
#   'punishment': 2,
#   'heresy': 1,
#   'httpstcouritrij1d6': 1,
#   'should': 19,
#   'nuclear': 9,
#   'weapons': 6,
#   'hands': 5,
#   'orã¢â‚¬â¦': 4,
#   'realjameswoods': 5,
#   'penises': 1,
#   'discuss': 1,
#   'spectator': 1,
#   'comment': 1,
#   'httpstcooc…': 1,
#   'inconvenient': 3,
#   'truth': 13,
#   'httpstcovyiicervue': 1,
#   'eladhutch': 2,
#   'colors': 1,
#   'rainbow': 1,
#   'abortion': 5,
#   'choice': 1,
#   '��': 12,
#   'liberallogic': 1,
#   'theeconomist': 1,
#   'wmo': 2,
#   'dont': 39,
#   'nature': 4,
#   'at': 47,
#   'work': 2,
#   'own': 6,
#   'wow': 6,
#   'what': 53,
#   'yesco2': 1,
#   'print': 1,
#   'seanspicier': 7,
#   'presidents': 2,
#   'regs': 2,
#   'california': 6,
#   'fall': 4,
#   'into': 21,
#   'pacific': 1,
#   'weekend': 2,
#   'plans': 4,
#   'reagantman': 1,
#   'media': 11,
#   'falsely': 2,
#   'spins': 1,
#   'trumps': 7,
#   'nyt': 3,
#   'comments': 2,
#   'cited': 1,
#   'climategate': 2,
#   'restated': 1,
#   'skepticism': 3,
#   'nickdsmith74': 1,
#   'fanatics': 4,
#   'frightened': 1,
#   'lord': 2,
#   'lawson': 1,
#   '4c': 1,
#   'tonight': 2,
#   'whens': 1,
#   'coming': 6,
#   'hmm': 1,
#   'qanda': 3,
#   'no': 84,
#   'asking': 2,
#   'liberal': 21,
#   'anything': 7,
#   'energy': 10,
#   'policy': 6,
#   'coal': 3,
#   'cnn': 16,
#   'damned': 1,
#   'ice': 26,
#   'egypt': 1,
#   'first': 11,
#   '112': 1,
#   'years😳😳😳': 1,
#   'thats': 15,
#   'ya🙄🙄': 1,
#   'httpstcotxmuir6no3': 1,
#   'cernovich': 5,
#   'experts': 7,
#   'said': 19,
#   'hillary': 10,
#   'win': 5,
#   'claim': 9,
#   'lol': 19,
#   'go': 18,
#   'morons': 9,
#   'know': 33,
#   'nothing': 20,
#   'losã¢â‚¬â¦': 5,
#   'premierbradwall': 1,
#   'think': 29,
#   'justintrudeau': 2,
#   'buying': 6,
#   'gullibility': 1,
#   'canadians': 1,
#   'regarding': 1,
#   'eldobleem': 1,
#   'any': 12,
#   'defend': 1,
#   'both': 5,
#   'inventors': 1,
#   'run': 3,
#   '��ok': 1,
#   'lets': 5,
#   'focus': 4,
#   'pic…': 1,
#   'independent': 2,
#   'rapes': 1,
#   'women': 6,
#   'wtf': 2,
#   'insane': 2,
#   'criminals': 1,
#   'today': 10,
#   'has': 55,
#   'some': 20,
#   'serious': 4,
#   'mental': 2,
#   'finally': 7,
#   'designed': 10,
#   'crooks': 3,
#   'crap': 10,
#   'httpstcovqc8e2lt6p': 2,
#   'anger': 2,
#   'conservative': 1,
#   'hurt': 2,
#   'american': 9,
#   'jobs': 9,
#   'insult': 1,
#   'crusade': 1,
#   'httpstcovy…': 1,
#   'nia4trump': 1,
#   'climatechange': 8,
#   '15': 7,
#   'trillion': 7,
#   'earth': 18,
#   'tho': 2,
#   'age': 5,
#   'fatties…': 1,
#   'johnkerry': 2,
#   'bullshit': 9,
#   'cofounder': 2,
#   'greenpeace': 2,
#   'even': 17,
#   'wrong': 7,
#   'suns': 1,
#   'activity': 4,
#   'fã¢â‚¬â¦': 1,
#   'httpstco3w9vuehabz': 1,
#   'samdastyari': 1,
#   'paulinehansonoz': 2,
#   'imagine': 2,
#   'hot': 12,
#   'otherwise': 2,
#   'gopchairwoman': 1,
#   'gop': 4,
#   'potus': 11,
#   'decision': 2,
#   'wasnt': 5,
#   'economics': 1,
#   'loss': 3,
#   'americans': 3,
#   'alyssamilano': 2,
#   'funding': 5,
#   'scam': 49,
#   'roncoleman': 1,
#   'didnt': 6,
#   'read': 15,
#   'assume': 1,
#   'antiscience': 3,
#   'become': 6,
#   'religion': 9,
#   'climatedepot': 7,
#   'report': 3,
#   'antarctica': 4,
#   'horrible': 3,
#   '–': 7,
#   'theblaze': 9,
#   'httpstcovax4a7drhl': 1,
#   'whistleblower': 6,
#   'admits': 10,
#   'scientists': 35,
#   'manipulated': 24,
#   'seem': 6,
#   'worse': 12,
#   'help': 6,
#   'httpstco87p2mchctx': 1,
#   'cattharmony': 1,
#   'id': 4,
#   'rather': 6,
#   'marchforbabies': 1,
#   'than': 29,
#   'httpstco5kigtgepgy': 1,
#   'nice': 3,
#   'arms': 1,
#   'race': 3,
#   'middle': 1,
#   'east': 1,
#   'wont': 9,
#   'around': 9,
#   'really': 16,
#   'experience': 1,
#   'wr…': 1,
#   'seanhannity': 4,
#   'probably': 4,
#   'shell': 1,
#   'voting': 1,
#   'candidate': 2,
#   'vagina': 1,
#   '3': 7,
#   'radical': 9,
#   'low': 1,
#   'tiny': 1,
#   'state': 5,
#   'rallying': 1,
#   'against': 11,
#   'issued': 1,
#   'healthcare': 2,
#   'industry': 2,
#   'sensanders': 7,
#   'normal': 3,
#   'planets': 4,
#   'process': 2,
#   'fooled': 2,
#   'lies': 9,
#   'thelanarchist': 1,
#   'geoengineering': 4,
#   'programs': 4,
#   'jets': 2,
#   'spraying': 1,
#   'arosols': 1,
#   'httpstcothvk08shki': 1,
#   'iluvspringtime': 1,
#   'once': 5,
#   'send': 4,
#   'lots': 2,
#   'moneygrants': 1,
#   'research': 14,
#   'watch': 11,
#   'quickly': 1,
#   'fad': 1,
#   'disappã¢â‚¬â¦': 1,
#   '800000': 1,
#   'years': 42,
#   'minutes': 1,
#   'proof': 12,
#   'mtco2': 1,
#   'debt': 3,
#   'httpstco7bbd09pjjd': 1,
#   'morningjoe': 1,
#   'joenbc': 1,
#   'causing': 8,
#   'min': 2,
#   'wage': 1,
#   'cost': 4,
#   'libs': 9,
#   'clueless': 1,
#   'bring': 3,
#   'industrial': 1,
#   'back': 12,
#   'america': 14,
#   'federal': 6,
#   'whistle': 5,
#   'blower': 5,
#   'charges': 3,
#   'fox': 3,
#   'httpstcotqcjb63ags': 1,
#   'alarmist': 5,
#   'warn': 1,
#   'potent': 1,
#   'hurricanes': 5,
#   'anyone': 10,
#   'lecturing': 4,
#   'behind': 10,
#   'simultaneously': 1,
#   'thinks': 5,
#   'genders': 3,
#   'heritage': 2,
#   'president': 10,
#   'resist': 2,
#   'pressure': 2,
#   'foreign': 3,
#   'leaders': 27,
#   'cave': 1,
#   'httpstco3spvjhcpu7': 1,
#   'joefreedomlove': 1,
#   'blog': 2,
#   'fights': 1,
#   'httpstcodjiqcdm5al': 1,
#   'nowthisnews': 2,
#   'pure': 2,
#   'fantasy': 1,
#   'noaa': 12,
#   'caught': 5,
#   'altering': 1,
#   'temps': 2,
#   'httpstcovb3ofbr06e': 1,
#   'surrender': 1,
#   'vestige': 1,
#   'interests': 1,
#   'past': 5,
#   'happened': 10,
#   'centuries': 1,
#   'noã¢â‚¬â¦': 1,
#   'httpstcojwgmrxmjgb': 1,
#   'rambogooner': 1,
#   'saying': 5,
#   '“don’t': 1,
#   'look': 14,
#   'sun”': 1,
#   'that’s': 1,
#   'lie': 10,
#   'thefoundingson': 1,
#   'temperature': 14,
#   'whos': 1,
#   'surprised': 1,
#   'httpstcorj…': 1,
#   'georgialogcabin': 1,
#   'noaas': 1,
#   'manipulation': 3,
#   'httpstcoflujjaawur': 1,
#   'economy': 4,
#   'national': 5,
#   'religious': 3,
#   'fundamentalism': 1,
#   'cult': 5,
#   'sprinkling': 1,
#   'of…': 2,
#   'httpstcovv8l1ztsgq': 1,
#   'markacollett': 1,
#   'biggest': 15,
#   'threat': 16,
#   'environment': 3,
#   'overpopulation': 1,
#   'fuelled': 1,
#   'aid': 2,
#   'thi…': 1,
#   'davidicke': 2,
#   'founder': 4,
#   'channel': 7,
#   'blasts': 1,
#   'total': 5,
#   'left…': 1,
#   'abc': 3,
#   'ya': 1,
#   'ass': 4,
#   'hat': 1,
#   'occurrence': 1,
#   'thousands': 3,
#   'o…': 3,
#   'httpstcokvdp3usb8m': 1,
#   'jonozalay': 1,
#   'heres': 1,
#   'pic': 1,
#   'arctic': 8,
#   'proving': 3,
#   'falling': 4,
#   'sex': 1,
#   'trafficking': 1,
#   'pizza': 1,
#   'parlor…': 1,
#   'junkscience': 11,
#   'decide': 2,
#   'attribute': 2,
#   'events': 3,
#   'httpstcopykvun6plz': 1,
#   'tengop': 4,
#   '7': 4,
#   'dead': 3,
#   'london': 4,
#   'oh': 13,
#   'wait': 10,
#   'nope': 4,
#   'islamic': 4,
#   'terrorism': 8,
#   'again': 14,
#   'londonattacks': 2,
#   'httpstcopuqc': 1,
#   'agency': 1,
#   'says': 19,
#   'common': 6,
#   'true': 5,
#   'httpstcocgai62hbxe': 1,
#   'aviwoolf': 1,
#   'leader': 2,
#   'free': 4,
#   'world': 37,
#   'syrian': 2,
#   'civil': 4,
#   'war': 7,
#   'cukoo': 1,
#   'land': 2,
#   'period': 2,
#   'httpstã¢â‚¬â¦': 5,
#   'donaldson': 1,
#   'standupforscience': 1,
#   'fact': 14,
#   'weve': 4,
#   'been': 35,
#   'changing': 7,
#   'our': 31,
#   'minds': 1,
#   'since': 15,
#   '1855': 1,
#   'httpstcoe6pu55dtnd': 1,
#   'foxnews': 12,
#   'ericbolling': 1,
#   'profitable': 3,
#   'hysteria': 7,
#   'business': 7,
#   'cashinin': 1,
#   'httpstcok0xk3fhriw': 1,
#   'hairtrigga': 1,
#   'donlemon': 1,
#   'cnntonight': 1,
#   'big': 14,
#   'money': 36,
#   'never': 18,
#   'rampant': 1,
#   'pollution': 3,
#   'ok': 5,
#   'am': 10,
#   'an': 26,
#   'avid': 1,
#   'outdoorsman': 1,
#   'chucknellis': 1,
#   'revealed': 4,
#   'httpstcogugt9rmyp7': 1,
#   'pope': 5,
#   'argentine': 1,
#   'jesuit': 1,
#   'liberation': 1,
#   'theology': 1,
#   'socialist': 2,
#   'firstclimate': 1,
#   'slaughter': 1,
#   'httpstcoqocytdg8el': 1,
#   'eugenevtooms': 1,
#   'rextilllerson': 2,
#   'cooling': 12,
#   'snowflake': 2,
#   'craigrbrittain': 2,
#   'acknowledging': 1,
#   'reports': 2,
#   '300': 2,
#   'denying': 2,
#   'clima…': 1,
#   'jimgilman': 1,
#   'joelquatro84': 1,
#   'mistercarter7': 1,
#   'uptownlinda': 1,
#   'washingtonpost': 5,
#   'admit': 1,
#   'yes': 13,
#   'f…': 3,
#   'httpstco3ikikdop7u': 1,
#   'sitting': 1,
#   'here': 10,
#   'waiting': 1,
#   'delayed': 1,
#   'flight': 1,
#   'watching': 3,
#   '5hrs': 1,
#   'theyve': 2,
#   'covered': 4,
#   'russia': 4,
#   'change…': 7,
#   'scientisttrump': 1,
#   '30º': 1,
#   'socalled': 6,
#   'now…': 1,
#   'differentiate': 1,
#   'between': 6,
#   'which': 19,
#   'occurring': 3,
#   'forever': 2,
#   'cha…': 1,
#   'httpstco0lgpp7gvpu': 1,
#   'disavowtrump16': 1,
#   'russwhitworth': 1,
#   'ill': 5,
#   'retweet': 2,
#   'shamelessly': 1,
#   'scandal': 1,
#   'fiddled': 1,
#   'httpstcoyerkoubzah': 1,
#   'climatescam': 3,
#   'greenscam': 1,
#   'teaparty': 1,
#   'tcot': 4,
#   'pjnet': 2,
#   'produces': 2,
#   '10c': 1,
#   'swings': 3,
#   'antarctic': 4,
#   '0c': 1,
#   'swings…': 1,
#   'combat': 5,
#   'having': 5,
#   'fing': 1,
#   'laugh': 2,
#   'httpstcoadqxkdgmze': 1,
#   'efbiltg': 1,
#   'buterastrology': 1,
#   'holocaust': 1,
#   'eyes': 1,
#   'wake': 5,
#   'up': 43,
#   'httpstcolyszb7ydcp': 2,
#   'httpstco79mxoe8w6m': 1,
#   'hankgreen': 1,
#   'blamed': 4,
#   'indus': 1,
#   'valley': 1,
#   'civ': 1,
#   'agonot': 1,
#   'humans': 10,
#   'pray': 2,
#   'ivanka': 1,
#   'stopping': 3,
#   'pushing': 4,
#   'her': 6,
#   'father': 2,
#   'httpstco6cvtw0oulo': 1,
#   'only': 25,
#   'meet': 4,
#   'face': 2,
#   ...}}

# %% [markdown]
# Next, we create a list of all of the unique words.

# %%
all_words = set()
for sent in sentiments_list:
    for word in sentiments[sent]: #getting the word in bag of words for a personality type
        all_words.add(word)

# %% [markdown]
# This was done so that we can create a combined bag of words dictionary for all the words in the text.

# %%
sentiments['all'] = {}
for sent in sentiments_list:    
    for word in all_words:
        if word in sentiments[sent].keys():
            if word in sentiments['all']:
                sentiments['all'][word] += sentiments[sent][word]
            else:
                sentiments['all'][word] = sentiments[sent][word]

# %%
sentiments['all']
# Out:
# {'watson': 3,
#  'best': 78,
#  '“sin': 1,
#  'congratulations': 4,
#  'bury': 10,
#  'httpstcomjjfij2csj': 1,
#  'futuã¢â‚¬â¦': 4,
#  'rammadhavbjp': 1,
#  '😍😌': 1,
#  'mourning': 5,
#  'httpstco28jzdqknuc': 1,
#  '2⃣': 1,
#  'poignant': 1,
#  'history': 46,
#  'leftã¢â‚¬â¦': 1,
#  'spider': 1,
#  'climatedeclaration': 1,
#  'surgeon': 2,
#  'policy…': 2,
#  'that’s': 19,
#  'embeezyj': 1,
#  'announces': 9,
#  'httpstco4wxnc3qyg5': 1,
#  'easiest': 4,
#  'httpstcoffg0yqcstq': 1,
#  'shows': 89,
#  'citiessun': 1,
#  'tabloid': 4,
#  'rollindaisies': 1,
#  'heye': 1,
#  'carfreenyc': 2,
#  'actinideage': 1,
#  'postcardjohn': 1,
#  'wreck': 4,
#  'politicomag': 2,
#  'httpstcoa6ha5ksk3p': 1,
#  'mast': 1,
#  'here’s': 18,
#  'substantiated': 1,
#  'edtech': 1,
#  'httpstcoodgppnilrw': 1,
#  'httpstcoyc14368e6p': 1,
#  'httpstcojbmzz8wooj': 1,
#  'httpstcocaocwsi…': 1,
#  '🇨🇦❄️☀️️': 1,
#  '74': 4,
#  'httpstcoimã¢â‚¬â¦': 1,
#  'nasaclimate': 3,
#  'sum': 1,
#  'httpstcotymlu6dbnm': 1,
#  'mayormontague': 1,
#  'engrkamaldeen': 1,
#  'httpstcovpfodfyc0k': 1,
#  'httpstcorfmaba8vp4': 1,
#  'gaston': 1,
#  'supply': 8,
#  'nkjemisin': 1,
#  'ready': 21,
#  'slipping': 1,
#  'interests…': 1,
#  'httpstcomqixobd1ja': 1,
#  'rude': 3,
#  'trumpification': 1,
#  'nye': 31,
#  'emerging': 3,
#  'achieving': 3,
#  'outcomes': 1,
#  'ayicckenya': 1,
#  'csislive': 1,
#  'httpstcorxrxxtdr3e': 1,
#  'merchantsofdoubt': 2,
#  'httpstcoumihh3mik3': 1,
#  'httpstco210d3mf0yd': 1,
#  'changetag': 1,
#  'anyall': 1,
#  'millennial': 4,
#  'calm': 8,
#  'persuade': 5,
#  'susannecraig': 1,
#  'yearsproject': 2,
#  'itizbiz': 1,
#  'taiwan': 5,
#  'djt4president': 1,
#  'epapruitt': 1,
#  'vote': 96,
#  'dwtkns': 1,
#  'httpstcoxduym5wjzo': 1,
#  'transforming': 3,
#  'httpstcoud4vee8v3n': 1,
#  'rlly': 1,
#  'staffer': 7,
#  'httpstcocgmybpi05t': 1,
#  '80': 20,
#  'co2is': 1,
#  'allegorical': 1,
#  'latinopriorities': 1,
#  'farting': 2,
#  'ppl¡¡¡': 1,
#  'revolution': 4,
#  'halloweens': 3,
#  'slays': 1,
#  'replamar': 1,
#  'pruitt': 224,
#  'ahlahni': 1,
#  'fiftybuckss': 1,
#  'extent': 6,
#  'contrast': 3,
#  'theprospect': 1,
#  'climatica': 1,
#  'robertivy': 1,
#  'seas…': 1,
#  'mmcauliff': 1,
#  'climatechangeshealth': 1,
#  'oregonian': 2,
#  'bil': 1,
#  'daysedge': 1,
#  'flipthe6th': 1,
#  'hssocialmedia': 1,
#  'trains': 1,
#  'whitehouse': 19,
#  'an…': 8,
#  'deseretnews': 1,
#  'httpstcodqaey0zeet': 1,
#  'denying': 142,
#  'planetearth': 1,
#  'httpstcofvois7emd1': 1,
#  'financial': 14,
#  '174': 1,
#  'dumber': 3,
#  'mbalter': 1,
#  'becoming': 16,
#  'winters': 8,
#  'priced': 1,
#  'ring': 6,
#  'snowfl…': 1,
#  'mislead': 2,
#  'httpstcoqj6tjcdzxj': 1,
#  'detgreenskills': 1,
#  'nobel': 7,
#  'katrina': 4,
#  'allenclifton': 1,
#  'httpstcoq9my0u…': 1,
#  'aquaculture': 1,
#  'httpstcoel0jjcfe46': 1,
#  'httpstcouupq83e8jq': 1,
#  'brilliantobiz…': 1,
#  'minds': 5,
#  'backwards': 9,
#  'httpstcobao7enlhvo': 1,
#  'adults': 7,
#  'httpstcodost1qpaqv': 1,
#  'httpstcoqfccu…': 1,
#  'going': 670,
#  'name': 36,
#  'zosterar': 1,
#  'override': 1,
#  'elegantly': 1,
#  'changefood': 1,
#  'pacts': 1,
#  'binge': 10,
#  '5th': 3,
#  'httpstcoalvqfbnmy7': 1,
#  'cleanpowerplan': 6,
#  'foreign': 14,
#  'httpstcoputpm0dp4f': 1,
#  'mateosfo': 1,
#  'bbcbreaking': 7,
#  'course': 45,
#  'indians': 3,
#  'leapmanifesto': 2,
#  'httpstcorlgrhhe7jt': 1,
#  'radical': 20,
#  'cognitivie': 1,
#  'complete': 8,
#  'alstoffel': 1,
#  'dylanw': 1,
#  'httpstcom5himouklo': 1,
#  'unsc': 2,
#  '❤️': 3,
#  'humanitynature': 1,
#  'princeton': 2,
#  'bathtaps': 1,
#  'stepped': 2,
#  'unethical…': 1,
#  'sustaininglife1': 1,
#  '200': 11,
#  'slsingh': 2,
#  'dirt': 2,
#  'httpstcoknste8k8im': 1,
#  'origin': 2,
#  'memories': 1,
#  'contains': 2,
#  'energiewende…': 1,
#  'davidkipping': 1,
#  'definitely': 13,
#  'unfollow': 2,
#  'ensuing': 1,
#  'httpstcocm2sex7up3': 1,
#  'vox': 4,
#  'snag': 1,
#  'sevmirzag': 1,
#  'utterly': 1,
#  'radioluke': 1,
#  'roparbarbara': 1,
#  'refusing': 3,
#  'very': 114,
#  'httpstcogl8s3zwmf4': 1,
#  'polarbears': 4,
#  'selective': 1,
#  'islanders': 3,
#  'marchforlife': 1,
#  'nationalgeograp': 1,
#  'fonda': 2,
#  'httpstcoilue2zt9mu…': 1,
#  'egotistical': 1,
#  'nuc…': 2,
#  'mikehudema': 3,
#  'httpstco3t3kn2ifnx': 1,
#  'gopled': 1,
#  'eriucc': 1,
#  'sierraclub': 26,
#  'punishpence': 1,
#  '✅': 1,
#  'carlzimmer': 3,
#  'greatgreatgreat': 1,
#  'recreation': 1,
#  'chubbahbubbah': 1,
#  'hates': 12,
#  'colonize': 1,
#  'never…': 1,
#  'nasagoddard': 2,
#  'httpstcofrb6owov4z': 1,
#  'warshs': 1,
#  'powerful': 35,
#  'httpstcof5jzzwl7cs': 1,
#  'mywishforthefuture': 1,
#  'httpstcoznunjvqlpy': 1,
#  'cybersygh': 4,
#  'yournewbooks': 1,
#  'poor': 45,
#  'disproportionally': 1,
#  'httpstcozolcjjtlde': 1,
#  'scarieststorys': 1,
#  'httpstcoilmcqmffdj': 1,
#  'httpstcogjmou8paur': 1,
#  'httpstcovsbqkjk5a8': 1,
#  'coollogistics': 1,
#  'buzzfeednews': 12,
#  'hmoindia': 1,
#  'httpstcouuoclodqo3': 1,
#  'greatgrandkids': 1,
#  'vã¢â‚¬â¦': 2,
#  'ther…': 1,
#  'needed…': 2,
#  'httpstcos85bwbr1bn': 1,
#  'httpstco0czl6l32uj': 1,
#  'offshore': 2,
#  'hittrentino': 1,
#  'httpstcokrekh5mdrb': 1,
#  'wmilam': 2,
#  'recognizing': 2,
#  'designtaxi': 1,
#  'being': 171,
#  'httpstcojpbahmctng': 1,
#  'vermont': 3,
#  'joanwalsh': 1,
#  'misselliemae': 2,
#  'httpstcotlpjje46tt': 1,
#  'cop': 2,
#  'uberpix': 1,
#  'honor…': 1,
#  'headass': 1,
#  'httpstcoggmgzn8b5z': 1,
#  'envorimentclimate': 1,
#  'lisalsong': 1,
#  'hack': 7,
#  'builds': 2,
#  'sajak': 1,
#  'fossiã¢â‚¬â¦': 24,
#  'wenns': 1,
#  'elephants': 2,
#  'started': 29,
#  'done': 51,
#  'httpstco9kbkst5giu': 1,
#  'marrakesh': 4,
#  'josh': 4,
#  '617b': 1,
#  'fraudulently': 1,
#  'living': 18,
#  'portfolios': 1,
#  'conversationus': 11,
#  'nygovcuomo': 5,
#  'httpstcojuma1p0cdt': 1,
#  'danagram': 1,
#  'america…': 1,
#  'hobbled': 1,
#  'c40': 2,
#  'palomafaith': 1,
#  'jesusguerreroh': 1,
#  'godlesspirate': 1,
#  'diabetes': 20,
#  'halema20': 1,
#  'httpstcojde57l8q0s': 1,
#  'apocalyptic': 3,
#  'colouring': 2,
#  'wan…': 2,
#  '2015’s': 1,
#  'frightening': 40,
#  'anyhow': 1,
#  'httpstco1jg0osqf7i': 1,
#  'briancdeese': 1,
#  'ac…': 1,
#  'measures…': 1,
#  'wereimmigrants': 1,
#  'administr…': 1,
#  'httpstcorzt6ikgpln': 1,
#  'including': 19,
#  'stick': 6,
#  'copy': 14,
#  'dailykos': 4,
#  'appraiser': 1,
#  'kelstarq': 1,
#  'memorize': 2,
#  'mrozatheist': 1,
#  'koenders': 1,
#  'humor': 2,
#  'httpstcoka19iywnb3': 1,
#  'davidsuzuki': 1,
#  'earthtotrump': 1,
#  'wed': 12,
#  'debate…': 1,
#  'altsmithsonian': 1,
#  'aplenty': 1,
#  'socialist': 3,
#  'mrkjsnsbyn': 1,
#  'immensely': 4,
#  'echoactionteam': 1,
#  'plans': 34,
#  'rotezukunft': 1,
#  'car': 14,
#  'stated': 4,
#  'fp': 1,
#  'blackvoices': 1,
#  'theeconomist': 24,
#  'looms': 3,
#  'removal': 4,
#  'southern': 12,
#  'whosimmortal': 1,
#  'invention': 2,
#  'protein': 2,
#  'httpstcoxua4ywbsq3': 1,
#  'schefferwill': 1,
#  'previous': 5,
#  'changeã¢â‚¬â€\x9dtake': 1,
#  'paulhawken': 1,
#  'century': 15,
#  '25th': 2,
#  'geoengineering': 6,
#  'soggy': 1,
#  'delete': 7,
#  'httpstcof54kql1m2e': 1,
#  'sb': 1,
#  'ashleighhookano': 1,
#  'httpstconqye5qbchk': 1,
#  'betterthemask': 1,
#  'immensity': 1,
#  'vegansfordonald': 1,
#  'mountaintop': 1,
#  'tolerate': 1,
#  'impactsummit': 1,
#  'canadianpm': 2,
#  'award': 5,
#  'others': 8,
#  'falsity': 1,
#  'period': 7,
#  'httpstcotjszngrzho': 1,
#  'jacquilambie': 1,
#  'deã¢â‚¬â¦': 4,
#  'restrictions': 3,
#  'httpstcohmg8mr8ohu': 1,
#  'fotoweekdc': 1,
#  'mercury': 7,
#  'healthandenv': 1,
#  'changescience': 1,
#  'nuttall': 3,
#  'family': 20,
#  'httpstconazqrcc1m0': 2,
#  'plnting': 1,
#  'httpstcobktxoqksxi': 1,
#  'josepgoded': 1,
#  'httpstcoeodscksehe': 1,
#  'vipin4vns': 1,
#  'viraimemes': 1,
#  'antonioparis': 1,
#  'greenpeaceindia': 1,
#  'mdrache': 1,
#  'httpstcovmemsngl5j': 1,
#  '1by': 1,
#  'cook': 2,
#  'httpstcomyldok3yã¢â‚¬â¦': 1,
#  'osmanakkoca': 3,
#  'dang…': 1,
#  '🔥': 1,
#  'differ…': 1,
#  'httpstcowixlig6lzp': 1,
#  'economic': 59,
#  'indias': 2,
#  'calendar': 1,
#  'lgb…': 1,
#  'eddyjokovich': 1,
#  'smartcities': 2,
#  'setting4success': 1,
#  'triggerhappy': 1,
#  'httpstcoi4ekzi4wh6': 1,
#  'shoplet': 1,
#  'ã¢â‚¬å“understanding': 1,
#  'fam': 1,
#  'pasmsu2': 1,
#  'afire': 1,
#  'begun': 8,
#  'httpstcok4cuetxguo': 1,
#  'httpstco7r8r0opyol': 1,
#  'abraham': 7,
#  'fire…': 2,
#  'ep…': 1,
#  'adopt…': 1,
#  '80th': 1,
#  'pentagonã¢â‚¬â„¢s': 2,
#  'httpstcocysu2r4rmn': 1,
#  'nhsdestroying': 1,
#  'fry': 1,
#  'ffrms': 1,
#  'contradicted': 1,
#  'httpstcoknimvitwtg': 1,
#  'smarter…': 1,
#  'refers': 1,
#  '60ã‚â°': 1,
#  'endangerment': 1,
#  'negotiations': 4,
#  'nypassivehouse': 1,
#  'pantomimevillain': 2,
#  'httpstcoetqm5xqor1': 1,
#  'httpstcobcsetex8bk': 1,
#  'g…': 10,
#  'socia…': 1,
#  'begging': 3,
#  'bobvulfov': 1,
#  'language': 11,
#  'cos': 5,
#  'liabilities': 1,
#  'httpstcohcjxi0ncrx': 1,
#  'lakota': 1,
#  'false': 18,
#  'michiganradio': 1,
#  'jonnyecology': 1,
#  'dresslikeawoman…': 1,
#  'httpstcoijay…': 1,
#  'grasses': 1,
#  'mena': 1,
#  'covers': 10,
#  'hostile': 2,
#  'pretty': 29,
#  'birdies4sanders': 2,
#  'dangillmor': 2,
#  'imvotingbecause': 62,
#  'httpstcoy0rfoe57nl': 1,
#  'china��oh': 1,
#  'autism…': 1,
#  'utah': 2,
#  'warmingmodel': 1,
#  'intellect': 1,
#  'httpstcoztnay…': 1,
#  'question…': 1,
#  'httpstcowplrihz8r0': 1,
#  'victory': 24,
#  'infesting': 1,
#  'httpstcos22iugbenu': 1,
#  'ga': 4,
#  'httpstcoe2omdbpui3': 1,
#  'ocean': 53,
#  'selling': 6,
#  '‘we': 2,
#  'grave': 4,
#  'genders': 4,
#  'stopkm': 1,
#  'allowed': 3,
#  'jumbo': 1,
#  'blowing': 2,
#  'coop': 1,
#  'anunnery': 1,
#  'stealing': 1,
#  'minimum': 30,
#  'mojado420': 1,
#  'coeruleus64': 1,
#  'rockefellerfdn': 1,
#  'sat': 2,
#  'jacob606': 1,
#  'solut…': 1,
#  'unison': 2,
#  'httpstconli9wvqhdq': 1,
#  'httpstcoo0dornmqi7': 1,
#  'ã°å¸å’â³lavendergreeã¢â‚¬â¦': 1,
#  'washington': 60,
#  '250k': 1,
#  'sophiewoood': 1,
#  'expelling': 2,
#  'httpstcofc5yxy4nwm': 1,
#  'httpstcozhw2momfxm': 1,
#  'httpstcoctyzdflgvg': 1,
#  'httpstco6kvyjnizfb': 1,
#  'mcm': 8,
#  'nationalfarmers': 1,
#  'httpstcoywqg0rpqo4': 1,
#  'elusive': 1,
#  'httpstcok0s2vrkc3k': 1,
#  'nilimajumder': 3,
#  'effects…': 1,
#  'iamjohnsparks': 1,
#  'thegreenpartys': 1,
#  'collapse': 13,
#  '180bn': 1,
#  'forgetdup': 1,
#  '350africa': 1,
#  'huma…': 1,
#  'notice': 10,
#  'citylab': 2,
#  'acknowledges': 2,
#  'few': 35,
#  'ukheatwave': 1,
#  'httpstcoewtqubg3hz': 1,
#  'willyum17': 1,
#  'of…': 12,
#  'wisconsin': 14,
#  'gaysampwomenwhite': 1,
#  'httpstcomqjvecreto': 1,
#  'santahasabadfeelingabout': 1,
#  'frankschaeffer': 1,
#  'ã¢â‚¬â€\x9dvp': 1,
#  'fitness': 1,
#  'classicgrrl': 1,
#  'ampã¢â‚¬â¦': 4,
#  'httpstcokb8hvkb5by': 1,
#  'certainsm1': 1,
#  'trump—humancaused': 1,
#  'thawing': 7,
#  'citiã¢â‚¬â¦': 1,
#  'misogynistic': 3,
#  'fried': 3,
#  'cares': 17,
#  'httpstcofbu3hhsdk5': 1,
#  'shenanagins': 1,
#  'nichellezinck': 1,
#  'jpvanypersele': 2,
#  'greeã¢â‚¬â¦': 1,
#  'httpstcocx5abrebln': 1,
#  'httpstco7hhmxlji1b': 1,
#  'kengarex': 3,
#  'doom': 11,
#  'phantomgoal': 1,
#  'theagu': 4,
#  'kate': 3,
#  'barbarastarrcnn': 1,
#  'colours': 2,
#  'forthleft2': 1,
#  'curriuculums': 1,
#  'atm': 1,
#  'gummer': 1,
#  'terminaiiychili': 1,
#  'imf': 1,
#  'expands': 2,
#  'solutions2030': 1,
#  'motherjones': 26,
#  'generals': 2,
#  'pak': 2,
#  'goals': 21,
#  'greensjeremy': 1,
#  'hardampfluid': 1,
#  'mitigation…': 1,
#  'other…': 3,
#  'drowning': 6,
#  '635': 1,
#  'trialã¢â‚¬â¦': 2,
#  'eriksolheimã¢â‚¬â¦': 1,
#  'conservs': 6,
#  'america': 157,
#  'prioritized': 2,
#  'httpstcobt5bfae8by': 1,
#  'republicanwho': 1,
#  'supporter': 7,
#  'httpstcouv3kd6nfvd': 1,
#  'crooks': 4,
#  'whats': 42,
#  'bizarro': 1,
#  'abolish': 2,
#  'httpstcoewr2hk3rwd': 1,
#  'globalprogress': 1,
#  'rampant': 3,
#  'denialon': 1,
#  'flatearth': 1,
#  'sing': 2,
#  'httpstcozedpahkdsp': 1,
#  'httpstcosxsv3fhfy9': 1,
#  'hope': 93,
#  'sniffinginla': 1,
#  'httpstco2dojã¢â‚¬â¦': 1,
#  'httpstcog1pxg0xo5b': 1,
#  'environmentalea': 1,
#  'mikemchargue': 3,
#  'mitamjensen': 1,
#  'httpstcojrrktq0evc': 1,
#  'httpstcopru1urjmo9': 1,
#  '2015': 15,
#  'httpstco2bg95stttz': 1,
#  'ecology': 2,
#  'eater': 1,
#  'submerged': 1,
#  'natureclimate': 3,
#  'moores': 2,
#  'concentrations': 3,
#  'booster': 1,
#  'reduced': 6,
#  'polli…': 1,
#  'idk': 7,
#  'httpstco5itsipzoyz': 1,
#  'dem': 8,
#  'httpstcok0v5yk7owh': 1,
#  'guardianaus': 6,
#  'httpstcooeydrjli5w': 1,
#  'destrã¢â‚¬â¦': 1,
#  'surreal': 1,
#  'srujanadeva': 1,
#  'httpstcoumcm6qmhcs': 1,
#  'rely': 5,
#  'streets': 6,
#  'httpstcoosir9zurgy': 1,
#  'urn': 1,
#  'httpstcouaybzebjhz': 1,
#  'httpstcocejqgdxksj': 1,
#  'grade': 6,
#  'httpstcoesvyejc7r…': 1,
#  'hillaryforsc': 1,
#  'endangered…': 1,
#  'resurr…': 1,
#  'grandchilã¢â‚¬â¦': 10,
#  'unprepared': 5,
#  'alexverbeek': 10,
#  'httpstcomfxgu4ygjm': 1,
#  'changeputin': 1,
#  'klein': 4,
#  'meryl': 1,
#  'system': 25,
#  'mad': 16,
#  'antivaccersclimate': 1,
#  'httpstco4spwzh7cfo': 1,
#  'kindly': 6,
#  '182': 1,
#  'unsettling': 2,
#  'fingers': 2,
#  'exec': 1,
#  'frozen': 5,
#  'httpstcobv7k6gfrgs': 1,
#  'httpstco0zqu6jn4al': 1,
#  'annual': 6,
#  'hayleyyjay': 1,
#  'joshbloch': 1,
#  'screen': 4,
#  'httpstcosfmhqckl32': 1,
#  'musicbut': 1,
#  'penalty': 3,
#  'solve': 49,
#  'coyntry': 1,
#  'decolonising': 1,
#  'jonathan': 4,
#  'ends': 7,
#  'california…': 1,
#  'ideology”': 4,
#  'cossadc': 1,
#  'studentsncl': 1,
#  'cyclonecharlie8': 1,
#  'sids': 3,
#  'sparked': 4,
#  'robfee': 2,
#  'paulajean2018': 1,
#  'sierrarise': 2,
#  'xxmere': 1,
#  'brxwncanadian': 1,
#  'tarszisz': 1,
#  'index': 6,
#  'httpstcocz9ql4nqc4': 1,
#  'mikebloomberg': 16,
#  'httpstcokbcrqeehtg': 1,
#  'hawksbills': 2,
#  'maaaaaadiison': 2,
#  'normornstein': 1,
#  'explains': 32,
#  'httpstcopc2buycmpb': 1,
#  'httpstcoeyip80einw': 1,
#  'invade': 2,
#  'attackin': 1,
#  'httpstcokdsg7x3ayw': 1,
#  'biblical': 1,
#  'httpstco2seeac3z…': 1,
#  'httpstcootosws2yxb': 1,
#  'ronplacone': 1,
#  'harrymcgee': 1,
#  'veryfawny': 1,
#  'hungry': 3,
#  'lending': 2,
#  'hoax…': 4,
#  'malcolm': 20,
#  'quadratic': 1,
#  'konk': 4,
#  'zer…': 1,
#  'congressmenwomen': 1,
#  'trumpleaks': 1,
#  'inform': 2,
#  'timothyswillis': 1,
#  'httpstcopbnpzxiya9': 1,
#  'greatbarrierreef': 16,
#  'smartcity': 1,
#  'operate': 1,
#  'httpstcog4iiwar1ee': 1,
#  'alive': 6,
#  'anz': 1,
#  'assumption': 2,
#  'pe…': 2,
#  'redtraccoon': 5,
#  'bradleym4': 1,
#  'octomom': 1,
#  'los…': 1,
#  'jr': 10,
#  'bein…': 2,
#  'httpstcozecxsunvzf': 1,
#  'tonyposnanski': 1,
#  'class': 25,
#  'cover': 16,
#  'alfonslopeztena': 2,
#  'dailyleopics': 1,
#  'crank': 1,
#  'clouds': 6,
#  'httpstcoypuagiqk2d': 1,
#  'httpstcopyecmayyag': 1,
#  'ã¢â‚¬â€\x9dã‚': 2,
#  'ejngreencareer': 1,
#  'emit': 4,
#  '‘hotspots’': 1,
#  'mexicanamerican': 1,
#  'advancements': 2,
#  '��for': 1,
#  'ibdeditorials': 1,
#  'beef': 14,
#  'httpstcoag7c3mbnrr': 1,
#  'idts': 1,
#  'moodtrble': 1,
#  'httpstcoaxbmuazx2a': 1,
#  'reparatioã¢â‚¬â¦': 1,
#  '■womens': 1,
#  'planteditors': 1,
#  'balling': 1,
#  'brian': 4,
#  'cigarettescancer': 1,
#  'aunz': 1,
#  'tourists': 1,
#  'httpstcouairxierxn': 1,
#  'decent': 2,
#  'httpstcon36cjgrmm2…': 1,
#  'diseases': 13,
#  'erikbryn': 2,
#  'dtrumpexposed': 2,
#  'shocked': 2,
#  'prometheusknows': 1,
#  '15°c': 8,
#  'animals': 34,
#  'renemarshcnn': 1,
#  'use': 89,
#  'httpstcoj7tjwrkpyp': 1,
#  'everyman': 1,
#  'commonwealth': 6,
#  'alias': 49,
#  'disrespectful': 1,
#  'genital': 1,
#  'httpsã¢â‚¬â¦': 106,
#  'climat…': 4,
#  'relied': 1,
#  'temperatures': 21,
#  'russelnorman': 1,
#  'fionaadorno': 1,
#  'httpstcol6wf0jgcwk': 1,
#  'andor': 3,
#  'summer': 20,
#  'thisdirectly': 1,
#  'trip': 9,
#  'sidestepped': 1,
#  'claus…': 1,
#  '‘direct': 1,
#  'lois': 1,
#  'tr…': 2,
#  'albertacantwait': 1,
#  'chummy': 1,
#  'affected': 39,
#  'emorwee': 4,
#  'httpstco3lbdtue5sa': 1,
#  'vastleft': 1,
#  'emis…': 1,
#  'warmingthats': 1,
#  'ivory': 2,
#  'httpstcoqhk5bwdi6f': 1,
#  'fakeunimportant': 1,
#  'greater': 8,
#  'transnational': 5,
#  'changehttpstco9ivpjylqps': 1,
#  'httpstcow8aww4y5ds': 1,
#  'nycjim': 1,
#  'millions': 169,
#  'httpstcoexqm1rygve': 1,
#  'httpstcobuxw…': 1,
#  'sierraclubwi': 1,
#  'fuckers': 1,
#  'flowering': 2,
#  'it—climate': 1,
#  'httpstcomuxrb6stoy': 1,
#  'pa…': 7,
#  'design': 3,
#  'lnp': 7,
#  'ricgallery': 1,
#  'decision': 33,
#  'nastywoman': 1,
#  'issued': 3,
#  'httpstcoh0klhenvax': 1,
#  'cruz': 2,
#  'httpstcoqlyqkbbjcg': 1,
#  'imwithher2016': 3,
#  'vermeulen': 1,
#  'httpstco5aemeingja': 1,
#  'httpstconsd9h7fzzl': 1,
#  'httpstcopxamhkapna': 1,
#  'antide…': 1,
#  'annaleen': 1,
#  'key': 64,
#  'httpstcodcidtxvfuj': 1,
#  'httpstco9ã¢â‚¬â¦': 3,
#  'people’': 1,
#  'exist': 67,
#  'httpstcoaorwhsvwhf': 1,
#  'size': 4,
#  'cope': 15,
#  '❄️⛄️��': 1,
#  'de…': 4,
#  'nigmachangeling': 1,
#  'httpstco6x4gxc7kgl': 1,
#  'minded': 4,
#  'kennedymiller24': 1,
#  'aprilfool': 1,
#  'phils': 1,
#  'huffingtonpost': 26,
#  'governornanok': 1,
#  'yasminyonis': 2,
#  'httpstco6oyvgewdmq': 1,
#  'melomys': 1,
#  'httpstcoavckxoxsx6': 1,
#  'creative': 3,
#  'today': 162,
#  'httpstco497wkkve58': 1,
#  'hoping': 6,
#  'tabbyterry': 1,
#  'missles': 1,
#  'deserve…': 1,
#  'tucker': 8,
#  'brunt': 1,
#  'stupid': 40,
#  'combine': 1,
#  'list': 25,
#  'diesel': 2,
#  'rampd': 1,
#  'rather’s': 1,
#  'privilege': 2,
#  'httpstcobedfyfu66l': 1,
#  'httpstcortt9mnm2nn': 1,
#  'geeksresist': 1,
#  'thomasb00001': 1,
#  'httpstco9dkwpfhyeb': 1,
#  'robert': 9,
#  'th': 3,
#  'propelling': 3,
#  'break': 18,
#  'httpstcowdtemunmj2': 1,
#  'attitude': 4,
#  'edwardhadas': 1,
#  'lookatthephoto': 1,
#  'dt': 5,
#  'adequately': 1,
#  'holocene': 1,
#  'jonathanchait': 6,
#  'httpstcobbzcjsh9…': 1,
#  'andrewsuleh': 1,
#  'clear': 36,
#  'exhale': 2,
#  'falling”': 1,
#  'flatearthers': 1,
#  'uganda’s': 1,
#  'pence': 16,
#  '3no': 1,
#  'mckenziewark': 1,
#  'sciencewilltellyou': 1,
#  'hurricanes': 29,
#  '59': 2,
#  'httpstcociajual9xj': 1,
#  'shirted…': 1,
#  'naomi': 7,
#  'httpstcoe88vigxmyz': 1,
#  'leadership': 44,
#  'canelo323': 1,
#  'democrat': 11,
#  'surge': 4,
#  'theyearofelan': 1,
#  'work': 93,
#  'feminist': 3,
#  'httpstcomklgacd43d': 1,
#  'httpstcohdubj2tlxn': 1,
#  'looming': 5,
#  'httpstcotvjumpeab9': 1,
#  'httpstcohotv3hrhaz': 1,
#  '127150…': 1,
#  'httpstcoodv…': 1,
#  'dhsgov': 1,
#  'wrp': 1,
#  'ontheground': 1,
#  'altering': 4,
#  'belly': 1,
#  'ecoconscious': 1,
#  'duycks': 2,
#  'heã¢â‚¬â„¢s': 1,
#  'httpstcogfe8xscaue': 1,
#  'httpstcofdfrcz2hel': 1,
#  'httpstcotkgn0cws9b': 1,
#  'enhanced': 4,
#  'imvoting4jillbecause': 1,
#  'coast': 18,
#  'focuses': 5,
#  'heroes': 7,
#  'cases': 5,
#  'geothermal': 1,
#  'beg': 4,
#  'ram': 2,
#  'httpstcog82abtfexd': 1,
#  'looks': 74,
#  'imperialism': 1,
#  'npennino70': 1,
#  'henryfong': 1,
#  'realized': 3,
#  'maj': 1,
#  'heartening': 1,
#  'thx': 4,
#  'hrc35': 1,
#  'httptcocmbxnvo637': 1,
#  'lonelyprobe': 1,
#  'unrelated': 2,
#  'carries': 1,
#  'hillisthekillis': 1,
#  'httpstcoqo4ygpim8w': 1,
#  'climatescience': 2,
#  'rene…': 1,
#  'polarbearsighting': 1,
#  'o…': 22,
#  'applicable': 2,
#  'andreagrimes': 1,
#  'kerry': 44,
#  'mindset': 1,
#  'ucc': 1,
#  'forecast': 10,
#  'alternative': 7,
#  'clp17': 1,
#  'httpstcoc8vwoiaq…': 1,
#  'worldfnature': 37,
#  'least': 35,
#  'clueless': 6,
#  'httpstcopcddou6w8m': 1,
#  'httpstconygvu8gmyn': 1,
#  'clings': 1,
#  'people': 600,
#  'mustread': 1,
#  'about…': 4,
#  'prayers…': 1,
#  'ghnextgen': 1,
#  'intention': 1,
#  'greatest': 21,
#  'changethreat': 1,
#  'kn…': 1,
#  'driver': 18,
#  'sour': 1,
#  'eliminated': 4,
#  'httpstco9h…': 1,
#  'ryanzinke': 1,
#  'httpstcozqsuxo7skm': 1,
#  'scared': 11,
#  'drvox': 14,
#  'amsa2017': 1,
#  'notourjustice': 1,
#  'httpstcoj…': 2,
#  'pains': 1,
#  ...}

# %% [markdown]
# Now we can easily calculate how many words there are in total.

# %%
total_words = sum([v for v in sentiments['all'].values()])
total_words
# Out:
# 278214

# %% [markdown]
# Go back to 'HOW DO MACHINES UNDERSTAND LANGUAGE FOR FURTHER SELECTION]
#
# ALSO CONSIDER OTHER NLP FETURE SELECTION METHODS YOU LEARNT LAST WEEK FRIDAY

# %% [markdown]
# ## Training

# %%
# Converting the collection of clean messages to a matrix of token counts
corpus = train_df['message']

vectorizer = CountVectorizer()
count_vectorized = vectorizer.fit_transform(corpus)
#print(vectorizer.get_feature_names())
#print(X.toarray())

# %%
# Converting the collection of clean messages to a matrix of TF-IDF features
data = train_df['message']

vectorizer=TfidfVectorizer(use_idf=True, max_df=0.95)
vectorized = vectorizer.fit_transform(data)
#print(vectorizer.get_feature_names())
#print(X.toarray())

# %%
# Using sparse to train the model using both representations.
import scipy.sparse

# Defining the features as well as the label
X = scipy.sparse.hstack([vectorized, count_vectorized])
y = train_df['sentiment']

# %%
from sklearn.model_selection import train_test_split

# Splitting the previously defined features and label of your dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Creating a list of all the models to train
lm = LogisticRegression(random_state = 5)

# %%
lm.fit(X_train,y_train)
# Out:
# C:\Users\msntu\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=5)

# %%
pred_lm = lm.predict(X_test)

# %%
print('Classification Report')
print(classification_report(y_test, pred_lm))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           -1       0.70      0.45      0.55       428
#            0       0.56      0.46      0.50       737
#            1       0.77      0.85      0.81      2861
#            2       0.74      0.75      0.75      1195
#
#     accuracy                           0.74      5221
#    macro avg       0.70      0.63      0.65      5221
# weighted avg       0.73      0.74      0.73      5221
